# %% [markdown]
# ## -- Stage 1: Load .mat files and apply a 50:1 imbalance to the raw signals (before segmentation).
# ## -- Stage 2: Segment signals into overlapping blocks (1600 samples, 320 interval) and one-hot encode labels for 10 classes.
# ## -- Stage 3: Perform an 80:20 class-wise time-based train-test split.

# %% [markdown]
# ## Set Up Environment

# %%
import tensorflow as tf
import numpy as np
import random
import pywt
from scipy.ndimage import zoom
import os
from skimage.transform import resize
from scipy import signal

# Set a fixed seed value for reproducibility
SEED = 1
random.seed(SEED)            # Python random module
np.random.seed(SEED)         # NumPy
tf.random.set_seed(SEED)     # TensorFlow

# Enforce deterministic behavior for GPU operations
os.environ['TF_DETERMINISTIC_OPS'] = '1'  # Ensure deterministic execution
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # Deterministic cuDNN algorithms

# Control GPU memory allocation (prevents TensorFlow from using all GPU memory)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)  # Enable memory growth

# Restrict parallelism (ensures consistent execution order)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

import os
import scipy.io 
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler
import numpy as np

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    log_loss,
    classification_report,
    confusion_matrix,
    roc_auc_score
)
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read CWRU Bearing Data (Load - 2HP)
# # --- Stage 1: Load CWRU Bearing Data ---

# %%
def load_and_imbalance_cwru_data(folder_path, imbalance_ratio=50):
    """
    Load CWRU bearing data from .mat files and apply imbalance to raw signals.

    Args:
        folder_path (str): Path to the directory containing .mat files.
        imbalance_ratio (int): Ratio of normal to fault signal lengths (default: 50).

    Returns:
        pd.DataFrame: DataFrame with columns 'Condition', 'Fault Size (mm)', 'Fault Label', 'Signal'.
    """
    data_dict = {
        'Condition': [],
        'Fault Size (mm)': [],
        'Fault Label': [],
        'Signal': []
    }

    conditions = [
        ('99.mat', 'Normal', 0, 0),
        ('124.mat', 'RE (Rolling element)', 0.18, 1),
        ('111.mat', 'IR (Inner ring)', 0.18, 2),
        ('137.mat', 'OR (Outer ring)', 0.18, 3),
        ('191.mat', 'RE (Rolling element)', 0.36, 4),
        ('176.mat', 'IR (Inner ring)', 0.36, 5),
        ('203.mat', 'OR (Outer ring)', 0.36, 6),
        ('228.mat', 'RE (Rolling element)', 0.54, 7),
        ('215.mat', 'IR (Inner ring)', 0.54, 8),
        ('240.mat', 'OR (Outer ring)', 0.54, 9)
    ]

    # Load normal signal to determine target length
    normal_signal = None
    for file_name, condition, fault_size, fault_label in conditions:
        if fault_label == 0:  # Normal class
            file_path = os.path.join(folder_path, file_name)
            file_number = file_name.split(".")[0].zfill(3)
            normal_signal = scipy.io.loadmat(file_path)[f'X{file_number}_DE_time'].flatten()
            break

    normal_length = len(normal_signal)
    target_fault_length = max(1000, normal_length // imbalance_ratio)  # Ensure minimum length for segmentation

    for file_name, condition, fault_size, fault_label in conditions:
        file_path = os.path.join(folder_path, file_name)
        file_number = file_name.split(".")[0].zfill(3)
        signal = scipy.io.loadmat(file_path)[f'X{file_number}_DE_time'].flatten()
        
        # Apply imbalance by subsampling fault signals
        if fault_label != 0:  # Fault classes
            if len(signal) > target_fault_length:
                signal = signal[:target_fault_length]
        
        data_dict['Condition'].append(condition)
        data_dict['Fault Size (mm)'].append(fault_size)
        data_dict['Fault Label'].append(fault_label)
        data_dict['Signal'].append(signal)

    df = pd.DataFrame(data_dict)
    print("\nRaw Signal Lengths After Imbalance Preprocessing:")
    for class_idx, row in df.iterrows():
        print(f"Class {class_idx} (Fault Label: {row['Fault Label']}, {row['Condition']}): {len(row['Signal'])} data points")

    return df

# %% [markdown]
# ## Data Processing and Feature Extraction with Imbalanced Data
#
# # --- Stage 2: Windowing with Overlap ---

# %%
def extract_segments(data, samples_per_block, interval_length, ignore_points=0):
    """
    Extract segments from data using vectorized indexing.

    Args:
        data (np.ndarray): Input signal data.
        samples_per_block (int): Length of each segment.
        interval_length (int): Step size between segment starts.
        ignore_points (int): Points to ignore at start and end.

    Returns:
        np.ndarray: Array of shape (n_segments, samples_per_block).
    """
    data = np.asarray(data).flatten()
    adjusted_length = len(data) - 2 * ignore_points
    n_segments = max(0, (adjusted_length - samples_per_block) // interval_length + 1)
    if n_segments == 0:
        return np.empty((0, samples_per_block), dtype=data.dtype)

    start_indices = ignore_points + np.arange(n_segments) * interval_length
    indices = start_indices[:, None] + np.arange(samples_per_block)
    return data[indices]

# %%
def min_max_norm(ary):
    ary = (ary - ary.min()) / np.abs(ary.max() - ary.min())
    return ary

def generate_spectrogram(segment, image_shape, fs=48000):
    f, t, spectrogram = signal.spectrogram(
        segment,
        fs,
        nperseg=256,
        # noverlap=128,
        window='hann'
    )
    spectrogram = min_max_norm(spectrogram)
    spectrogram = resize(spectrogram, image_shape, mode='constant', anti_aliasing=True)
    return spectrogram

# %%
def segment_and_generate_spectrograms(df, image_shape, samples_per_block, interval_length, n_classes):
    segment_list = []
    one_hot_labels = []
    integer_labels = []

    for class_idx, row in df.iterrows():
        signal = row['Signal']
        fault_label = row['Fault Label']
        condition = row['Condition']

        segments = extract_segments(signal, samples_per_block, interval_length)
        n_segments = segments.shape[0]

        spectrograms = np.array([generate_spectrogram(seg, image_shape, fs=48000) for seg in segments])

        print(f"\nClass {class_idx} (Fault Label: {fault_label}, {condition}):")
        print(f"Segments: {n_segments} segments")
        print(f"spectrogram shape: {spectrograms.shape}")

        if n_segments > 0:
            one_hot = np.zeros((n_segments, n_classes))
            one_hot[:, class_idx] = 1
            labels = np.full((n_segments, 1), class_idx)

            segment_list.append(spectrograms)
            one_hot_labels.append(one_hot)
            integer_labels.append(labels)

    return segment_list, one_hot_labels, integer_labels

# %% [markdown]
# # --- Stage 3: Imbalance ---

# %%
def preprocess_train_for_imbalance(segments, labels, imbalance_ratio=50):
    """
    Apply imbalance preprocessing to sampled training segments to achieve specified ratio.

    Args:
        segments (List[np.ndarray]): List of sampled segment arrays (n_segments, samples_per_block).
        labels (List[int]): List of corresponding fault labels.
        imbalance_ratio (int): Ratio of normal to fault segments (default: 50).

    Returns:
        List[np.ndarray]: List of preprocessed training segment arrays.
    """
    processed_segments = []
    normal_segments = next((seg for seg, lbl in zip(segments, labels) if lbl == 0), np.array([]))
    n_normal_segments = normal_segments.shape[0]
    target_fault_segments = max(1, n_normal_segments // imbalance_ratio)

    for segment_array, fault_label in zip(segments, labels):
        n_segments = segment_array.shape[0]
        if n_segments == 0:
            print(f"No segments available for Fault Label {fault_label}. Skipping.")
            processed_segments.append(np.array([]).reshape(0, segment_array.shape[1]))
            continue
        target = n_normal_segments if fault_label == 0 else target_fault_segments
        selected_segments = segment_array[:min(target, n_segments)]
        processed_segments.append(selected_segments)
    return processed_segments

# %% [markdown]
# # --- Time-Based Train-Test Split

# %%
def time_train_test_split(segment_list, one_hot_labels, integer_labels, df, train_ratio=0.8, n_classes=10):
    """
    Perform time-based class-wise train-test split.

    Args:
        segment_list (List[np.ndarray]): List of segment arrays per class.
        one_hot_labels (List[np.ndarray]): List of one-hot encoded label arrays.
        integer_labels (List[np.ndarray]): List of integer label arrays.
        df (pd.DataFrame): DataFrame with 'Signal', 'Fault Label', 'Condition'.
        train_ratio (float): Fraction of data for training.
        n_classes (int): Number of classes.

    Returns:
        tuple: (X_train, X_test, Y_train, Y_test, y_train, y_test)
            - X_ are 4D arrays for CNN (n_samples, 40, 40, 1).
            - Y_ are one-hot labels (n_samples, n_classes).
            - y_ are integer labels (n_samples, 1).
    """
    X_train_list, X_test_list = [], []
    Y_train_list, Y_test_list = [], []
    y_train_list, y_test_list = [], []

    post_split_train_lengths = []
    post_split_test_lengths = []

    image_shape = (96, 96)

    fault_labels = df['Fault Label'].values
    conditions = df['Condition'].values

    for class_idx, (signal, segments, one_hot, integer, fault_label, condition) in enumerate(
        zip(df['Signal'], segment_list, one_hot_labels, integer_labels, fault_labels, conditions)
    ):
        n_segments = segments.shape[0]
        train_size = int(n_segments * train_ratio)
        train_segments = segments[:train_size]
        test_segments = segments[train_size:]

        post_split_train_lengths.append((class_idx, fault_label, condition, train_segments.shape[0]))
        post_split_test_lengths.append((class_idx, fault_label, condition, test_segments.shape[0]))

        if train_segments.shape[0] > 0:
            train_one_hot = one_hot[:train_size]
            train_labels = integer[:train_size]
            X_train_list.append(train_segments)
            Y_train_list.append(train_one_hot)
            y_train_list.append(train_labels)

        if test_segments.shape[0] > 0:
            test_one_hot = one_hot[train_size:]
            test_labels = integer[train_size:]
            X_test_list.append(test_segments)
            Y_test_list.append(test_one_hot)
            y_test_list.append(test_labels)

        print(f"\nClass {class_idx} (Fault Label: {fault_label}, {condition}):")
        print(f"Train segments (post-split): {train_segments.shape[0]} segments")
        print(f"Test segments (post-split): {test_segments.shape[0]} segments")
        # print(f"Sample train data (first 5 elements): {train_segments[0][:5] if train_segments.shape[0] > 0 else 'Empty'}")
        # print(f"Sample test data (first 5 elements): {test_segments[0][:5] if test_segments.shape[0] > 0 else 'Empty'}")

    print("\nTraining Segments After Split:")
    for class_idx, fault_label, condition, segment_count in post_split_train_lengths:
        print(f"Class {class_idx} (Fault Label: {fault_label}, {condition}): {segment_count} segments")

    print("\nTest Segments After Split:")
    for class_idx, fault_label, condition, segment_count in post_split_test_lengths:
        print(f"Class {class_idx} (Fault Label: {fault_label}, {condition}): {segment_count} segments")

    X_train = np.vstack(X_train_list) if X_train_list else np.empty((0, 1600))
    X_test = np.vstack(X_test_list) if X_test_list else np.empty((0, 1600))
    Y_train = np.vstack(Y_train_list) if Y_train_list else np.empty((0, n_classes))
    Y_test = np.vstack(Y_test_list) if Y_test_list else np.empty((0, n_classes))
    y_train = np.vstack(y_train_list) if y_train_list else np.empty((0, 1))
    y_test = np.vstack(y_test_list) if y_test_list else np.empty((0, 1))

    X_2D_train = X_train.reshape([-1, image_shape[0], image_shape[1], 1])
    X_2D_test = X_test.reshape([-1, image_shape[0], image_shape[1], 1])

    print(f"\nFinal X_train shape: {X_2D_train.shape}")
    # print(f"Sample X_train values (first 5 elements): {X_train[0][:5] if X_train.size > 0 else 'Empty'}")
    print(f"Final Y_train shape: {Y_train.shape}")
    # print(f"Sample Y_train values (first 5): {Y_train[:5] if Y_train.size > 0 else 'Empty'}")
    print(f"Final y_train shape: {y_train.shape}")
    # print(f"Sample y_train values (first 5): {y_train[:5] if y_train.size > 0 else 'Empty'}")
    print(f"\nFinal X_test shape: {X_2D_test.shape}")
    # print(f"Sample X_test values (first 5 elements): {X_test[0][:5] if X_test.size > 0 else 'Empty'}")
    print(f"Final Y_test shape: {Y_test.shape}")
    # print(f"Sample Y_test values (first 5): {Y_test[:5] if Y_test.size > 0 else 'Empty'}")
    print(f"Final y_test shape: {y_test.shape}")
    # print(f"Sample y_test values (first 5): {y_test[:5] if y_test.size > 0 else 'Empty'}")

    return X_2D_train, X_2D_test, Y_train, Y_test, y_train, y_test

# %%
# --- Execution ---
folder_path = './CWRU_BearingData_Load_2HP'
interval_length = 320
samples_per_block = 1600
n_classes = 10
train_ratio = 0.8
imbalance_ratio = 50

# Stage 1: Load and apply imbalance
df = load_and_imbalance_cwru_data(folder_path, imbalance_ratio)

# Stage 2: Segment signals and generate spectrograms
segments, one_hot_labels, integer_labels = segment_and_generate_spectrograms(df, image_shape=(96, 96), samples_per_block=1600, interval_length=320, n_classes=10)

# Stage 3: Train-test split
X_2D_train, X_2D_test, Y_train, Y_test, y_label_train, y_label_test = time_train_test_split(
    segments, one_hot_labels, integer_labels, df, train_ratio, n_classes
)
# Out:
# Raw Signal Lengths After Imbalance Preprocessing:
# Class 0 (Fault Label: 0, Normal): 485063 data points
# Class 1 (Fault Label: 1, RE (Rolling element)): 9701 data points
# Class 2 (Fault Label: 2, IR (Inner ring)): 9701 data points
# Class 3 (Fault Label: 3, OR (Outer ring)): 9701 data points
# Class 4 (Fault Label: 4, RE (Rolling element)): 9701 data points
# Class 5 (Fault Label: 5, IR (Inner ring)): 9701 data points
# Class 6 (Fault Label: 6, OR (Outer ring)): 9701 data points
# Class 7 (Fault Label: 7, RE (Rolling element)): 9701 data points
# Class 8 (Fault Label: 8, IR (Inner ring)): 9701 data points
# Class 9 (Fault Label: 9, OR (Outer ring)): 9701 data points
#
# Class 0 (Fault Label: 0, Normal):
# Segments: 1511 segments
# spectrogram shape: (1511, 96, 96)
#
# Class 1 (Fault Label: 1, RE (Rolling element)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 2 (Fault Label: 2, IR (Inner ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 3 (Fault Label: 3, OR (Outer ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 4 (Fault Label: 4, RE (Rolling element)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 5 (Fault Label: 5, IR (Inner ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 6 (Fault Label: 6, OR (Outer ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 7 (Fault Label: 7, RE (Rolling element)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 8 (Fault Label: 8, IR (Inner ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 9 (Fault Label: 9, OR (Outer ring)):
# Segments: 26 segments
# spectrogram shape: (26, 96, 96)
#
# Class 0 (Fault Label: 0, Normal):
# Train segments (post-split): 1208 segments
# Test segments (post-split): 303 segments
#
# Class 1 (Fault Label: 1, RE (Rolling element)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 2 (Fault Label: 2, IR (Inner ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 3 (Fault Label: 3, OR (Outer ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 4 (Fault Label: 4, RE (Rolling element)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 5 (Fault Label: 5, IR (Inner ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 6 (Fault Label: 6, OR (Outer ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 7 (Fault Label: 7, RE (Rolling element)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 8 (Fault Label: 8, IR (Inner ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Class 9 (Fault Label: 9, OR (Outer ring)):
# Train segments (post-split): 20 segments
# Test segments (post-split): 6 segments
#
# Training Segments After Split:
# Class 0 (Fault Label: 0, Normal): 1208 segments
# Class 1 (Fault Label: 1, RE (Rolling element)): 20 segments
# Class 2 (Fault Label: 2, IR (Inner ring)): 20 segments
# Class 3 (Fault Label: 3, OR (Outer ring)): 20 segments
# Class 4 (Fault Label: 4, RE (Rolling element)): 20 segments
# Class 5 (Fault Label: 5, IR (Inner ring)): 20 segments
# Class 6 (Fault Label: 6, OR (Outer ring)): 20 segments
# Class 7 (Fault Label: 7, RE (Rolling element)): 20 segments
# Class 8 (Fault Label: 8, IR (Inner ring)): 20 segments
# Class 9 (Fault Label: 9, OR (Outer ring)): 20 segments
#
# Test Segments After Split:
# Class 0 (Fault Label: 0, Normal): 303 segments
# Class 1 (Fault Label: 1, RE (Rolling element)): 6 segments
# Class 2 (Fault Label: 2, IR (Inner ring)): 6 segments
# Class 3 (Fault Label: 3, OR (Outer ring)): 6 segments
# Class 4 (Fault Label: 4, RE (Rolling element)): 6 segments
# Class 5 (Fault Label: 5, IR (Inner ring)): 6 segments
# Class 6 (Fault Label: 6, OR (Outer ring)): 6 segments
# Class 7 (Fault Label: 7, RE (Rolling element)): 6 segments
# Class 8 (Fault Label: 8, IR (Inner ring)): 6 segments
# Class 9 (Fault Label: 9, OR (Outer ring)): 6 segments
#
# Final X_train shape: (1388, 96, 96, 1)
# Final Y_train shape: (1388, 10)
# Final y_train shape: (1388, 1)
#
# Final X_test shape: (357, 96, 96, 1)
# Final Y_test shape: (357, 10)
# Final y_test shape: (357, 1)

# %% [markdown]
# ## Multiclass Classification CNN Model Training with Imbalanced Data

# %%
import numpy as np
import pandas as pd

# Condition mapping
condition_map = {
    0: "Normal",
    1: "RE 0.18",
    2: "IR 0.18",
    3: "OR 0.18",
    4: "RE 0.36",
    5: "IR 0.36",
    6: "OR 0.36",
    7: "RE 0.54",
    8: "IR 0.54",
    9: "OR 0.54"
}

# X_train distribution (using Y_train)
unique, counts = np.unique(np.argmax(Y_train, axis=1), return_counts=True)
df_train_orig = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique],
    'Blocks': counts
})
print("Blocks per class in X_train:")
print(df_train_orig.to_string(index=False))

# Train set distribution (using Y_train, same as above since no additional split)
train_classes = np.argmax(Y_train, axis=1)
unique_train, counts_train = np.unique(train_classes, return_counts=True)
df_train = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique_train],
    'Blocks': counts_train
})
print("\nX_train_split and Y_train distribution:")
print(df_train.to_string(index=False))

# Test set distribution (using Y_test)
test_classes = np.argmax(Y_test, axis=1)
unique_test, counts_test = np.unique(test_classes, return_counts=True)
df_test = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique_test],
    'Blocks': counts_test
})
print("\nX_test_split and Y_test distribution:")
print(df_test.to_string(index=False))

# # y_train_split and y_test_split (same as Y_train and Y_test distributions)
# print("\ny_train_split distribution (assumed):")
# print(df_train.to_string(index=False))
# print("\ny_test_split distribution (assumed):")
# print(df_test.to_string(index=False))
# Out:
# Blocks per class in X_train:
# Condition  Blocks
#    Normal    1208
#   RE 0.18      20
#   IR 0.18      20
#   OR 0.18      20
#   RE 0.36      20
#   IR 0.36      20
#   OR 0.36      20
#   RE 0.54      20
#   IR 0.54      20
#   OR 0.54      20
#
# X_train_split and Y_train distribution:
# Condition  Blocks
#    Normal    1208
#   RE 0.18      20
#   IR 0.18      20
#   OR 0.18      20
#   RE 0.36      20
#   IR 0.36      20
#   OR 0.36      20
#   RE 0.54      20
#   IR 0.54      20
#   OR 0.54      20
#
# X_test_split and Y_test distribution:
# Condition  Blocks
#    Normal     303
#   RE 0.18       6
#   IR 0.18       6
#   OR 0.18       6
#   RE 0.36       6
#   IR 0.36       6
#   OR 0.36       6
#   RE 0.54       6
#   IR 0.54       6
#   OR 0.54       6

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
print(f"X_2D_train shape: {X_2D_train.shape}")  # Expected: (num_samples, 1600, 1)
print(f"X_2D_test shape: {X_2D_test.shape}")    # Expected: (num_samples, 1600, 1)
X_2D_train, X_2D_test, Y_train, Y_test, y_label_train, y_label_test

class CNN_2D():
    def __init__(self):
        self.model = self.CreateModel()

    def CreateModel(self):
        model = models.Sequential([
            layers.Conv2D(32, (3, 3), padding='same', input_shape=(96, 96, 1)),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.Conv2D(32, (3, 3), padding='same'),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Conv2D(64, (3, 3), padding='same'),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.Conv2D(64, (3, 3), padding='same'),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Conv2D(128, (3, 3), padding='same'),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.Conv2D(128, (3, 3), padding='same'),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(100),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.Dropout(0.5),
            layers.Dense(96),
            layers.BatchNormalization(),
            layers.Activation('relu'),
            layers.Dense(10, activation='softmax')
        ])
        model.compile(
            optimizer='adam',
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model
# Out:
# X_2D_train shape: (1388, 96, 96, 1)
# X_2D_test shape: (357, 96, 96, 1)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential, load_model
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, balanced_accuracy_score

# Condition mapping
condition_map = {
    0: "Normal",
    1: "RE 0.18",
    2: "IR 0.18",
    3: "OR 0.18",
    4: "RE 0.36",
    5: "IR 0.36",
    6: "OR 0.36",
    7: "RE 0.54",
    8: "IR 0.54",
    9: "OR 0.54"
}

# Training with k-fold validation
foldername = "CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/"
kSplits = 5
accuracy_1D = []
precision_1D = []
recall_1D = []
f1_1D = []
log_loss_1D = []
balanced_accuracy_1D = []
accuracy_1D_test = []
precision_1D_test = []
recall_1D_test = []
f1_1D_test = []
log_loss_1D_test = []
balanced_accuracy_1D_test = []

# Initialize arrays for validation predictions across folds
n_train_samples = Y_train.shape[0]
pred_all_val = np.zeros((n_train_samples, 10))  # Store validation predictions
y_val_true = np.zeros((n_train_samples, 10))    # Store true validation labels
kfold_test_len = []                             # Store size of each validation fold
fl1 = 0

early_stop = EarlyStopping(monitor='val_accuracy', patience=50, restore_best_weights=True)
kfold = StratifiedKFold(n_splits=kSplits, random_state=42, shuffle=True)

# Train the model with k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_2D_train, y_label_train.flatten())):
    checkpoint_filepath = foldername + f"best_model_fold_{fold+1}.h5"
    checkpoint = ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
    Classification_2D = CNN_2D()
    history = Classification_2D.model.fit(
        X_2D_train[train_idx], Y_train[train_idx],
        validation_data=(X_2D_train[val_idx], Y_train[val_idx]),
        epochs=200,
        verbose=1,
        callbacks=[checkpoint, early_stop]
    )
    print(f"Best model saved at: {checkpoint_filepath}")
    CNN_2D_best_model = load_model(checkpoint_filepath)
    print("Best model loaded successfully!")

    # Store validation predictions
    fl2 = fl1 + len(val_idx)
    pred_all_val[fl1:fl2, :] = CNN_2D_best_model.predict(X_2D_train[val_idx])
    y_val_true[fl1:fl2, :] = Y_train[val_idx]
    kfold_test_len.append(fl2 - fl1)
    fl1 = fl2

    # Train set metrics (for the current fold's training data)
    y_pred_proba_train = CNN_2D_best_model.predict(X_2D_train[train_idx])
    y_pred_train = np.argmax(y_pred_proba_train, axis=1)
    y_true_train = np.argmax(Y_train[train_idx], axis=1)

    accuracy_1D.append(accuracy_score(y_true_train, y_pred_train))
    precision_1D.append(precision_score(y_true_train, y_pred_train, average='weighted'))
    recall_1D.append(recall_score(y_true_train, y_pred_train, average='weighted'))
    f1_1D.append(f1_score(y_true_train, y_pred_train, average='weighted'))
    log_loss_1D.append(log_loss(Y_train[train_idx], y_pred_proba_train))
    balanced_accuracy_1D.append(balanced_accuracy_score(y_true_train, y_pred_train))

    # Test set metrics
    y_pred_proba_test = CNN_2D_best_model.predict(X_2D_test)
    y_pred_test = np.argmax(y_pred_proba_test, axis=1)
    y_true_test = np.argmax(Y_test, axis=1)

    accuracy_1D_test.append(accuracy_score(y_true_test, y_pred_test))
    precision_1D_test.append(precision_score(y_true_test, y_pred_test, average='weighted'))
    recall_1D_test.append(recall_score(y_true_test, y_pred_test, average='weighted'))
    f1_1D_test.append(f1_score(y_true_test, y_pred_test, average='weighted'))
    log_loss_1D_test.append(log_loss(Y_test, y_pred_proba_test))
    balanced_accuracy_1D_test.append(balanced_accuracy_score(y_true_test, y_pred_test))

# Print average metrics across folds
print("\nAverage Training Metrics Across Folds:")
print(f"Accuracy: {np.mean(accuracy_1D):.4f} ± {np.std(accuracy_1D):.4f}")
print(f"Precision: {np.mean(precision_1D):.4f} ± {np.std(precision_1D):.4f}")
print(f"Recall: {np.mean(recall_1D):.4f} ± {np.std(recall_1D):.4f}")
print(f"F1 Score: {np.mean(f1_1D):.4f} ± {np.std(f1_1D):.4f}")
print(f"Log Loss: {np.mean(log_loss_1D):.4f} ± {np.std(log_loss_1D):.4f}")
print(f"Balanced Accuracy: {np.mean(balanced_accuracy_1D):.4f} ± {np.std(balanced_accuracy_1D):.4f}")

print("\nAverage Test Metrics Across Folds:")
print(f"Accuracy: {np.mean(accuracy_1D_test):.4f} ± {np.std(accuracy_1D_test):.4f}")
print(f"Precision: {np.mean(precision_1D_test):.4f} ± {np.std(precision_1D_test):.4f}")
print(f"Recall: {np.mean(recall_1D_test):.4f} ± {np.std(recall_1D_test):.4f}")
print(f"F1 Score: {np.mean(f1_1D_test):.4f} ± {np.std(f1_1D_test):.4f}")
print(f"Log Loss: {np.mean(log_loss_1D_test):.4f} ± {np.std(log_loss_1D_test):.4f}")
print(f"Balanced Accuracy: {np.mean(balanced_accuracy_1D_test):.4f} ± {np.std(balanced_accuracy_1D_test):.4f}")

# Distribution printing (from previous request)
unique, counts = np.unique(np.argmax(Y_train, axis=1), return_counts=True)
df_train_orig = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique],
    'Blocks': counts
})
print("\nBlocks per class in X_train:")
print(df_train_orig.to_string(index=False))

train_classes = np.argmax(Y_train, axis=1)
unique_train, counts_train = np.unique(train_classes, return_counts=True)
df_train = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique_train],
    'Blocks': counts_train
})
print("\nX_train_split and Y_train distribution:")
print(df_train.to_string(index=False))

test_classes = np.argmax(Y_test, axis=1)
unique_test, counts_test = np.unique(test_classes, return_counts=True)
df_test = pd.DataFrame({
    'Condition': [condition_map[l] for l in unique_test],
    'Blocks': counts_test
})
print("\nX_test_split and Y_test distribution:")
print(df_test.to_string(index=False))

print("\ny_train_split distribution (assumed):")
print(df_train.to_string(index=False))
print("\ny_test_split distribution (assumed):")
print(df_test.to_string(index=False))
# Out:
# /Users/Gayathri/pyenvs/tf-env/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 2025-07-01 22:51:47.701463: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-07-01 22:51:47.702116: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6739 - loss: 1.3323
# 2025-07-01 22:52:47.899376: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-07-01 22:52:47.900246: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Epoch 1: val_accuracy improved from -inf to 0.01439, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.6774 - loss: 1.3227 - val_accuracy: 0.0144 - val_loss: 4.0233
# Epoch 2/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8745 - loss: 0.4879
# Epoch 2: val_accuracy did not improve from 0.01439
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.8749 - loss: 0.4861 - val_accuracy: 0.0144 - val_loss: 5.0102
# Epoch 3/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8839 - loss: 0.3805
# Epoch 3: val_accuracy did not improve from 0.01439
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.8841 - loss: 0.3794 - val_accuracy: 0.0144 - val_loss: 4.5830
# Epoch 4/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9081 - loss: 0.2925
# Epoch 4: val_accuracy did not improve from 0.01439
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9083 - loss: 0.2919 - val_accuracy: 0.0144 - val_loss: 5.0269
# Epoch 5/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9014 - loss: 0.2638
# Epoch 5: val_accuracy did not improve from 0.01439
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9021 - loss: 0.2630 - val_accuracy: 0.0144 - val_loss: 3.5083
# Epoch 6/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9203 - loss: 0.2356
# Epoch 6: val_accuracy did not improve from 0.01439
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9206 - loss: 0.2349 - val_accuracy: 0.0144 - val_loss: 1.8792
# Epoch 7/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9340 - loss: 0.2038
# Epoch 7: val_accuracy improved from 0.01439 to 0.88489, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9342 - loss: 0.2032 - val_accuracy: 0.8849 - val_loss: 0.9864
# Epoch 8/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9297 - loss: 0.2050
# Epoch 8: val_accuracy improved from 0.88489 to 0.89928, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9300 - loss: 0.2044 - val_accuracy: 0.8993 - val_loss: 0.6345
# Epoch 9/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9316 - loss: 0.1852
# Epoch 9: val_accuracy did not improve from 0.89928
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.9319 - loss: 0.1846 - val_accuracy: 0.5540 - val_loss: 1.2331
# Epoch 10/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9538 - loss: 0.1394
# Epoch 10: val_accuracy did not improve from 0.89928
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9539 - loss: 0.1392 - val_accuracy: 0.7986 - val_loss: 0.9743
# Epoch 11/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9520 - loss: 0.1445
# Epoch 11: val_accuracy improved from 0.89928 to 0.91007, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9523 - loss: 0.1440 - val_accuracy: 0.9101 - val_loss: 0.3248
# Epoch 12/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9492 - loss: 0.1492
# Epoch 12: val_accuracy improved from 0.91007 to 0.91367, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9496 - loss: 0.1485 - val_accuracy: 0.9137 - val_loss: 0.3399
# Epoch 13/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9525 - loss: 0.1351
# Epoch 13: val_accuracy improved from 0.91367 to 0.93525, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9529 - loss: 0.1343 - val_accuracy: 0.9353 - val_loss: 0.2249
# Epoch 14/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9645 - loss: 0.1142
# Epoch 14: val_accuracy did not improve from 0.93525
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9649 - loss: 0.1134 - val_accuracy: 0.9353 - val_loss: 0.1877
# Epoch 15/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9762 - loss: 0.0883
# Epoch 15: val_accuracy did not improve from 0.93525
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9763 - loss: 0.0879 - val_accuracy: 0.6043 - val_loss: 1.0320
# Epoch 16/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9796 - loss: 0.0889
# Epoch 16: val_accuracy improved from 0.93525 to 0.94604, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9797 - loss: 0.0886 - val_accuracy: 0.9460 - val_loss: 0.1581
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9968 - loss: 0.0132
# Epoch 44: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9968 - loss: 0.0132 - val_accuracy: 0.9640 - val_loss: 0.1250
# Epoch 45/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9852 - loss: 0.0430
# Epoch 45: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9853 - loss: 0.0428 - val_accuracy: 0.9460 - val_loss: 0.2641
# Epoch 46/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9864 - loss: 0.0457
# Epoch 46: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9864 - loss: 0.0456 - val_accuracy: 0.7914 - val_loss: 0.7801
# Epoch 47/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9801 - loss: 0.0528
# Epoch 47: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9803 - loss: 0.0525 - val_accuracy: 0.9640 - val_loss: 0.1911
# Epoch 48/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9934 - loss: 0.0205
# Epoch 48: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9934 - loss: 0.0205 - val_accuracy: 0.9568 - val_loss: 0.1761
# Epoch 49/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9927 - loss: 0.0264
# Epoch 49: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9927 - loss: 0.0264 - val_accuracy: 0.9173 - val_loss: 0.4119
# Epoch 50/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9910 - loss: 0.0275
# Epoch 50: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9911 - loss: 0.0274 - val_accuracy: 0.9245 - val_loss: 0.3463
# Epoch 51/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9899 - loss: 0.0270
# Epoch 51: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9900 - loss: 0.0269 - val_accuracy: 0.9209 - val_loss: 0.3752
# Epoch 52/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9941 - loss: 0.0207
# Epoch 52: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9940 - loss: 0.0208 - val_accuracy: 0.9388 - val_loss: 0.2724
# Epoch 53/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9934 - loss: 0.0201
# Epoch 53: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9934 - loss: 0.0201 - val_accuracy: 0.9856 - val_loss: 0.0571
# Epoch 54/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9999 - loss: 0.0083
# Epoch 54: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9999 - loss: 0.0083 - val_accuracy: 0.9892 - val_loss: 0.0581
# Epoch 55/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9975 - loss: 0.0101
# Epoch 55: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.9856 - val_loss: 0.0673
# Epoch 56/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9948 - loss: 0.0121
# Epoch 56: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9948 - loss: 0.0121 - val_accuracy: 0.9784 - val_loss: 0.1060
# Epoch 57/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9992 - loss: 0.0075
# Epoch 57: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9992 - loss: 0.0076 - val_accuracy: 0.9712 - val_loss: 0.1132
# Epoch 58/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9997 - loss: 0.0074
# Epoch 58: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9997 - loss: 0.0074 - val_accuracy: 0.9784 - val_loss: 0.1214
# Epoch 59/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 59: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9784 - val_loss: 0.0769
# Epoch 60/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9988 - loss: 0.0065
# Epoch 60: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9988 - loss: 0.0064 - val_accuracy: 0.9820 - val_loss: 0.0666
# Epoch 61/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 55: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9317 - val_loss: 0.3231
# Epoch 56/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 56: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9317 - val_loss: 0.3212
# Epoch 57/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9993 - loss: 0.0039
# Epoch 57: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9993 - loss: 0.0039 - val_accuracy: 0.9568 - val_loss: 0.2040
# Epoch 58/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9982 - loss: 0.0063
# Epoch 58: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9982 - loss: 0.0064 - val_accuracy: 0.9460 - val_loss: 0.1593
# Epoch 59/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9958 - loss: 0.0143
# Epoch 59: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9957 - loss: 0.0145 - val_accuracy: 0.9317 - val_loss: 0.2771
# Epoch 60/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9789 - loss: 0.0770
# Epoch 60: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9790 - loss: 0.0764 - val_accuracy: 0.9532 - val_loss: 0.1603
# Epoch 61/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9683 - loss: 0.1053
# Epoch 61: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9684 - loss: 0.1047 - val_accuracy: 0.9640 - val_loss: 0.1601
# Epoch 62/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9836 - loss: 0.0503
# Epoch 62: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9836 - loss: 0.0506 - val_accuracy: 0.9532 - val_loss: 0.1972
# Epoch 63/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9758 - loss: 0.0600
# Epoch 63: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9760 - loss: 0.0594 - val_accuracy: 0.9532 - val_loss: 0.1579
# Epoch 64/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9915 - loss: 0.0343
# Epoch 64: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9916 - loss: 0.0340 - val_accuracy: 0.9173 - val_loss: 0.4005
# Epoch 65/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9960 - loss: 0.0147
# Epoch 65: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9961 - loss: 0.0146 - val_accuracy: 0.8993 - val_loss: 0.3828
# Epoch 66/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9945 - loss: 0.0168
# Epoch 66: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.9209 - val_loss: 0.3171
# Epoch 67/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9974 - loss: 0.0108
# Epoch 67: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9974 - loss: 0.0108 - val_accuracy: 0.8993 - val_loss: 0.3813
# Epoch 68/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9994 - loss: 0.0051
# Epoch 68: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.9317 - val_loss: 0.2873
# Epoch 69/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9984 - loss: 0.0050
# Epoch 69: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.9209 - val_loss: 0.2971
# Epoch 70/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 70: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9640 - val_loss: 0.1128
# Epoch 71/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9953 - loss: 0.0095
# Epoch 71: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9954 - loss: 0.0094 - val_accuracy: 0.9784 - val_loss: 0.0673
# Epoch 72/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9964 - loss: 0.0060
# Epoch 72: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9964 - loss: 0.0060 - val_accuracy: 0.9748 - val_loss: 0.0751
# Epoch 73/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9984 - loss: 0.0078
# Epoch 73: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9983 - loss: 0.0079 - val_accuracy: 0.9820 - val_loss: 0.0494
# Epoch 74/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9951 - loss: 0.0165
# Epoch 74: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9951 - loss: 0.0165 - val_accuracy: 0.9460 - val_loss: 0.3493
# Epoch 75/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9937 - loss: 0.0131
# Epoch 75: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9938 - loss: 0.0131 - val_accuracy: 0.3129 - val_loss: 1.9158
# Epoch 76/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9929 - loss: 0.0217
# Epoch 76: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9930 - loss: 0.0214 - val_accuracy: 0.2014 - val_loss: 2.6688
# Epoch 77/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9990 - loss: 0.0041
# Epoch 77: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9990 - loss: 0.0041 - val_accuracy: 0.4892 - val_loss: 1.1995
# Epoch 78/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9991 - loss: 0.0045
# Epoch 78: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9640 - val_loss: 0.3639
# Epoch 79/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 79: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9820 - val_loss: 0.2319
# Epoch 80/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9997 - loss: 0.0036
# Epoch 80: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9997 - loss: 0.0036 - val_accuracy: 0.9676 - val_loss: 0.0786
# Epoch 81/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 81: val_accuracy did not improve from 0.98921
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9712 - val_loss: 0.0982
# Epoch 82/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9998 - loss: 0.0042
# Epoch 57: val_accuracy did not improve from 0.98917
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9998 - loss: 0.0043 - val_accuracy: 0.9819 - val_loss: 0.0371
# Epoch 58/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 58: val_accuracy did not improve from 0.98917
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9856 - val_loss: 0.0616
# Epoch 59/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9998 - loss: 0.0032
# Epoch 59: val_accuracy improved from 0.98917 to 0.99278, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9928 - val_loss: 0.0352
# Epoch 60/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9993 - loss: 0.0044
# Epoch 60: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9993 - loss: 0.0044 - val_accuracy: 0.9928 - val_loss: 0.0151
# Epoch 61/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 61: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9892 - val_loss: 0.0196
# Epoch 62/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9982 - loss: 0.0075
# Epoch 62: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9982 - loss: 0.0075 - val_accuracy: 0.9747 - val_loss: 0.1822
# Epoch 63/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 63: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9892 - val_loss: 0.0213
# Epoch 64/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9988 - loss: 0.0051
# Epoch 64: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9856 - val_loss: 0.0218
# Epoch 65/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.9935 - loss: 0.0166
# Epoch 65: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 472s 14s/step - accuracy: 0.9935 - loss: 0.0167 - val_accuracy: 0.8087 - val_loss: 0.6376
# Epoch 66/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 62s/step - accuracy: 0.9962 - loss: 0.0167
# Epoch 66: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2100s 62s/step - accuracy: 0.9963 - loss: 0.0166 - val_accuracy: 0.9495 - val_loss: 0.2004
# Epoch 67/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 199s/step - accuracy: 0.9937 - loss: 0.0246
# Epoch 67: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6770s 199s/step - accuracy: 0.9938 - loss: 0.0244 - val_accuracy: 0.3394 - val_loss: 1.7625
# Epoch 68/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 125s/step - accuracy: 0.9977 - loss: 0.0107
# Epoch 68: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5256s 125s/step - accuracy: 0.9976 - loss: 0.0108 - val_accuracy: 0.2491 - val_loss: 2.2382
# Epoch 69/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 108s/step - accuracy: 0.9991 - loss: 0.0107
# Epoch 69: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3675s 108s/step - accuracy: 0.9990 - loss: 0.0107 - val_accuracy: 0.6787 - val_loss: 1.0399
# Epoch 70/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 115s/step - accuracy: 0.9952 - loss: 0.0364
# Epoch 70: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3904s 115s/step - accuracy: 0.9952 - loss: 0.0359 - val_accuracy: 0.7581 - val_loss: 0.7029
# Epoch 71/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 63s/step - accuracy: 0.9948 - loss: 0.0110
# Epoch 71: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2158s 63s/step - accuracy: 0.9949 - loss: 0.0109 - val_accuracy: 0.2455 - val_loss: 1.7666
# Epoch 72/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9960 - loss: 0.0129
# Epoch 72: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9960 - loss: 0.0128 - val_accuracy: 0.9711 - val_loss: 0.2758
# Epoch 73/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9975 - loss: 0.0053
# Epoch 73: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9975 - loss: 0.0053 - val_accuracy: 0.9819 - val_loss: 0.0483
# Epoch 74/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9958 - loss: 0.0118
# Epoch 74: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9959 - loss: 0.0117 - val_accuracy: 0.9783 - val_loss: 0.0787
# Epoch 75/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9996 - loss: 0.0052
# Epoch 75: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9996 - loss: 0.0052 - val_accuracy: 0.9783 - val_loss: 0.0791
# Epoch 76/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9971 - loss: 0.0104
# Epoch 76: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9970 - loss: 0.0107 - val_accuracy: 0.9567 - val_loss: 0.1214
# Epoch 77/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.0343
# Epoch 77: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9892 - loss: 0.0342 - val_accuracy: 0.0686 - val_loss: 5.6543
# Epoch 78/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9938 - loss: 0.0170
# Epoch 78: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9938 - loss: 0.0171 - val_accuracy: 0.9711 - val_loss: 0.1235
# Epoch 79/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9954 - loss: 0.0166
# Epoch 79: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9954 - loss: 0.0166 - val_accuracy: 0.9892 - val_loss: 0.0465
# Epoch 80/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9942 - loss: 0.0144
# Epoch 80: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9943 - loss: 0.0144 - val_accuracy: 0.9856 - val_loss: 0.1954
# Epoch 81/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9989 - loss: 0.0088
# Epoch 81: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9989 - loss: 0.0087 - val_accuracy: 0.9856 - val_loss: 0.0443
# Epoch 82/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0106
# Epoch 82: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9928 - loss: 0.0106 - val_accuracy: 0.9928 - val_loss: 0.0514
# Epoch 83/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9977 - loss: 0.0079
# Epoch 83: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.9928 - val_loss: 0.0366
# Epoch 84/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9998 - loss: 0.0037
# Epoch 84: val_accuracy improved from 0.99278 to 0.99639, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9998 - loss: 0.0038 - val_accuracy: 0.9964 - val_loss: 0.0164
# Epoch 85/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 85: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9892 - val_loss: 0.0318
# Epoch 86/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9966 - loss: 0.0106
# Epoch 86: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9966 - loss: 0.0106 - val_accuracy: 0.9856 - val_loss: 0.0473
# Epoch 87/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9960 - loss: 0.0183
# Epoch 87: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9960 - loss: 0.0182 - val_accuracy: 0.9603 - val_loss: 0.2838
# Epoch 88/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9979 - loss: 0.0124
# Epoch 88: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9979 - loss: 0.0123 - val_accuracy: 0.9892 - val_loss: 0.0742
# Epoch 89/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9962 - loss: 0.0094
# Epoch 89: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9962 - loss: 0.0095 - val_accuracy: 0.9134 - val_loss: 0.3956
# Epoch 90/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.0341
# Epoch 90: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9893 - loss: 0.0339 - val_accuracy: 0.9856 - val_loss: 0.0586
# Epoch 91/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9967 - loss: 0.0160
# Epoch 91: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9967 - loss: 0.0159 - val_accuracy: 0.9964 - val_loss: 0.0139
# Epoch 92/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9958 - loss: 0.0144
# Epoch 92: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9958 - loss: 0.0144 - val_accuracy: 0.9856 - val_loss: 0.0761
# Epoch 93/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9997 - loss: 0.0068
# Epoch 93: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9997 - loss: 0.0068 - val_accuracy: 0.9928 - val_loss: 0.0383
# Epoch 94/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - loss: 0.0031
# Epoch 94: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9928 - val_loss: 0.0218
# Epoch 95/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 95: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9892 - val_loss: 0.0338
# Epoch 96/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 96: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9819 - val_loss: 0.0406
# Epoch 97/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 97: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9892 - val_loss: 0.0296
# Epoch 98/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9986 - loss: 0.0056
# Epoch 98: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9986 - loss: 0.0055 - val_accuracy: 0.9892 - val_loss: 0.0139
# Epoch 99/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 99: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9892 - val_loss: 0.0188
# Epoch 100/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 100: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9892 - val_loss: 0.0306
# Epoch 101/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 101: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9892 - val_loss: 0.0286
# Epoch 102/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0040
# Epoch 102: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 0.9928 - val_loss: 0.0421
# Epoch 103/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 103: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9928 - val_loss: 0.0482
# Epoch 104/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9998 - loss: 0.0015
# Epoch 104: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9928 - val_loss: 0.0355
# Epoch 105/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 105: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9928 - val_loss: 0.0278
# Epoch 106/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 106: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9928 - val_loss: 0.0236
# Epoch 107/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9992 - loss: 0.0029
# Epoch 107: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 186s 5s/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9856 - val_loss: 0.0389
# Epoch 108/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9962 - loss: 0.0088
# Epoch 108: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9962 - loss: 0.0088 - val_accuracy: 0.9856 - val_loss: 0.0830
# Epoch 109/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 109: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9819 - val_loss: 0.0749
# Epoch 110/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9996 - loss: 0.0022
# Epoch 110: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9819 - val_loss: 0.0444
# Epoch 111/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 111: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9856 - val_loss: 0.0590
# Epoch 112/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 112: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9856 - val_loss: 0.0348
# Epoch 113/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9993 - loss: 0.0046
# Epoch 113: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9993 - loss: 0.0046 - val_accuracy: 0.9856 - val_loss: 0.0639
# Epoch 114/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9962 - loss: 0.0076
# Epoch 114: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9962 - loss: 0.0077 - val_accuracy: 0.9819 - val_loss: 0.0471
# Epoch 115/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9998 - loss: 0.0040
# Epoch 115: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 0.9928 - val_loss: 0.0331
# Epoch 116/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0030
# Epoch 116: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9856 - val_loss: 0.0589
# Epoch 117/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9996 - loss: 0.0029
# Epoch 117: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9996 - loss: 0.0029 - val_accuracy: 0.9928 - val_loss: 0.0278
# Epoch 118/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 8.6186e-04
# Epoch 118: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 8.7168e-04 - val_accuracy: 0.9928 - val_loss: 0.0469
# Epoch 119/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 119: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9928 - val_loss: 0.0431
# Epoch 120/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 120: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9928 - val_loss: 0.0494
# Epoch 121/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0016
# Epoch 121: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 0.9928 - val_loss: 0.0611
# Epoch 122/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 8.4736e-04
# Epoch 122: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 1.0000 - loss: 8.4707e-04 - val_accuracy: 0.9892 - val_loss: 0.0356
# Epoch 123/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 123: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9964 - val_loss: 0.0175
# Epoch 124/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9976 - loss: 0.0023
# Epoch 124: val_accuracy improved from 0.99639 to 1.00000, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_4.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9977 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 125/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 125: val_accuracy did not improve from 1.00000
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 126/200
# 29/35 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9973 - loss: 0.0041
# Epoch 30: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9970 - loss: 0.0156 - val_accuracy: 0.9495 - val_loss: 0.2643
# Epoch 31/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9956 - loss: 0.0196
# Epoch 31: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9956 - loss: 0.0196 - val_accuracy: 0.9350 - val_loss: 0.4905
# Epoch 32/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - accuracy: 0.9902 - loss: 0.0247
# Epoch 32: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 976s 29s/step - accuracy: 0.9902 - loss: 0.0247 - val_accuracy: 0.3357 - val_loss: 1.7787
# Epoch 33/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9975 - loss: 0.0179
# Epoch 33: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9975 - loss: 0.0179 - val_accuracy: 0.1083 - val_loss: 2.2028
# Epoch 34/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 0.9938 - loss: 0.0215
# Epoch 34: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 968s 28s/step - accuracy: 0.9939 - loss: 0.0214 - val_accuracy: 0.4838 - val_loss: 1.3494
# Epoch 35/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9975 - loss: 0.0133
# Epoch 35: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9975 - loss: 0.0134 - val_accuracy: 0.1300 - val_loss: 2.0808
# Epoch 36/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9974 - loss: 0.0145
# Epoch 36: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9974 - loss: 0.0147 - val_accuracy: 0.9422 - val_loss: 0.3992
# Epoch 37/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - accuracy: 0.9993 - loss: 0.0136
# Epoch 37: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1101s 32s/step - accuracy: 0.9992 - loss: 0.0136 - val_accuracy: 0.9783 - val_loss: 0.1279
# Epoch 38/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9950 - loss: 0.0197
# Epoch 38: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9950 - loss: 0.0197 - val_accuracy: 0.9422 - val_loss: 0.2319
# Epoch 39/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0181
# Epoch 39: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9946 - loss: 0.0181 - val_accuracy: 0.9675 - val_loss: 0.2730
# Epoch 40/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - accuracy: 0.9945 - loss: 0.0208
# Epoch 40: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1005s 30s/step - accuracy: 0.9946 - loss: 0.0207 - val_accuracy: 0.8989 - val_loss: 0.4864
# Epoch 41/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9968 - loss: 0.0125
# Epoch 41: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.7112 - val_loss: 0.8373
# Epoch 42/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9996 - loss: 0.0072
# Epoch 42: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9996 - loss: 0.0072 - val_accuracy: 0.9603 - val_loss: 0.2359
# Epoch 43/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - accuracy: 0.9995 - loss: 0.0077
# Epoch 43: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 977s 29s/step - accuracy: 0.9995 - loss: 0.0077 - val_accuracy: 0.9711 - val_loss: 0.1424
# Epoch 44/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9993 - loss: 0.0073
# Epoch 44: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9992 - loss: 0.0075 - val_accuracy: 0.9856 - val_loss: 0.0652
# Epoch 45/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9970 - loss: 0.0112
# Epoch 45: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1016s 30s/step - accuracy: 0.9970 - loss: 0.0112 - val_accuracy: 0.9458 - val_loss: 0.1877
# Epoch 46/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9993 - loss: 0.0059
# Epoch 46: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9993 - loss: 0.0059 - val_accuracy: 0.9422 - val_loss: 0.2191
# Epoch 47/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 47: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9783 - val_loss: 0.2177
# Epoch 48/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 19s/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 48: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 647s 19s/step - accuracy: 0.9999 - loss: 0.0044 - val_accuracy: 0.5307 - val_loss: 1.0242
# Epoch 49/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0044
# Epoch 49: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9999 - loss: 0.0045 - val_accuracy: 0.9711 - val_loss: 0.2667
# Epoch 50/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9988 - loss: 0.0061
# Epoch 50: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9988 - loss: 0.0061 - val_accuracy: 0.9892 - val_loss: 0.0721
# Epoch 51/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 51: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 961s 28s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9819 - val_loss: 0.0540
# Epoch 52/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 52: val_accuracy did not improve from 0.99278
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9892 - val_loss: 0.0240
# Epoch 53/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 53: val_accuracy improved from 0.99278 to 0.99639, saving model to CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_5.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9964 - val_loss: 0.0120
# Epoch 54/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 54: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1015s 30s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9819 - val_loss: 0.0310
# Epoch 55/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 55: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9964 - val_loss: 0.0243
# Epoch 56/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 56: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 972s 29s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9892 - val_loss: 0.0376
# Epoch 57/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 57: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9856 - val_loss: 0.0490
# Epoch 58/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 0.0084
# Epoch 58: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9947 - loss: 0.0084 - val_accuracy: 0.9819 - val_loss: 0.0582
# Epoch 59/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9995 - loss: 0.0035
# Epoch 59: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9995 - loss: 0.0036 - val_accuracy: 0.9819 - val_loss: 0.0649
# Epoch 60/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9990 - loss: 0.0047
# Epoch 60: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9747 - val_loss: 0.0793
# Epoch 61/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0035
# Epoch 61: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9999 - loss: 0.0036 - val_accuracy: 0.9928 - val_loss: 0.0284
# Epoch 62/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 62: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9892 - val_loss: 0.0222
# Epoch 63/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 63: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9242 - val_loss: 0.2672
# Epoch 64/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 64: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9278 - val_loss: 0.2333
# Epoch 65/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - accuracy: 0.9986 - loss: 0.0033
# Epoch 65: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1024s 30s/step - accuracy: 0.9986 - loss: 0.0033 - val_accuracy: 0.9783 - val_loss: 0.0773
# Epoch 66/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 66: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1089s 32s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9892 - val_loss: 0.0404
# Epoch 67/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 67: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9856 - val_loss: 0.0478
# Epoch 68/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 68: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9711 - val_loss: 0.1192
# Epoch 69/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - loss: 0.0052
# Epoch 69: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1046s 2s/step - accuracy: 0.9990 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1109
# Epoch 70/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9791 - loss: 0.0638
# Epoch 70: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9790 - loss: 0.0644 - val_accuracy: 0.8881 - val_loss: 0.8189
# Epoch 71/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 0.9655 - loss: 0.1230
# Epoch 71: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 956s 28s/step - accuracy: 0.9656 - loss: 0.1224 - val_accuracy: 0.9458 - val_loss: 0.2332
# Epoch 72/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9830 - loss: 0.0474
# Epoch 72: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9830 - loss: 0.0474 - val_accuracy: 0.9531 - val_loss: 0.2025
# Epoch 73/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9896 - loss: 0.0290
# Epoch 73: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9897 - loss: 0.0288 - val_accuracy: 0.9675 - val_loss: 0.1628
# Epoch 74/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9983 - loss: 0.0119
# Epoch 74: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9983 - loss: 0.0118 - val_accuracy: 0.9819 - val_loss: 0.0866
# Epoch 75/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9944 - loss: 0.0162
# Epoch 75: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9944 - loss: 0.0162 - val_accuracy: 0.9892 - val_loss: 0.0262
# Epoch 76/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9967 - loss: 0.0111
# Epoch 76: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9967 - loss: 0.0111 - val_accuracy: 0.9819 - val_loss: 0.0392
# Epoch 77/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9985 - loss: 0.0112
# Epoch 77: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9985 - loss: 0.0113 - val_accuracy: 0.9892 - val_loss: 0.0343
# Epoch 78/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9994 - loss: 0.0061
# Epoch 78: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9994 - loss: 0.0061 - val_accuracy: 0.9856 - val_loss: 0.0325
# Epoch 79/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 79: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9747 - val_loss: 0.0654
# Epoch 80/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9999 - loss: 0.0035
# Epoch 80: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9999 - loss: 0.0035 - val_accuracy: 0.9856 - val_loss: 0.0307
# Epoch 81/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 81: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9783 - val_loss: 0.0532
# Epoch 82/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9996 - loss: 0.0031
# Epoch 82: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9996 - loss: 0.0031 - val_accuracy: 0.9711 - val_loss: 0.0984
# Epoch 83/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9996 - loss: 0.0028
# Epoch 83: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9819 - val_loss: 0.0493
# Epoch 84/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9997 - loss: 0.0025
# Epoch 84: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 0.9278 - val_loss: 0.2530
# Epoch 85/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9992 - loss: 0.0031
# Epoch 85: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9675 - val_loss: 0.1035
# Epoch 86/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 86: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9747 - val_loss: 0.0535
# Epoch 87/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 87: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9675 - val_loss: 0.1049
# Epoch 88/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 88: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9928 - val_loss: 0.0199
# Epoch 89/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 89: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9928 - val_loss: 0.0116
# Epoch 90/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9977 - loss: 0.0074
# Epoch 90: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9856 - val_loss: 0.0575
# Epoch 91/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9910 - loss: 0.0710
# Epoch 91: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9910 - loss: 0.0701 - val_accuracy: 0.9711 - val_loss: 0.2177
# Epoch 92/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.0239
# Epoch 92: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9938 - loss: 0.0241 - val_accuracy: 0.9819 - val_loss: 0.0741
# Epoch 93/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0341
# Epoch 93: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9887 - loss: 0.0339 - val_accuracy: 0.9603 - val_loss: 0.2769
# Epoch 94/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9886 - loss: 0.0363
# Epoch 94: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9886 - loss: 0.0361 - val_accuracy: 0.9819 - val_loss: 0.0890
# Epoch 95/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9998 - loss: 0.0097
# Epoch 95: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9998 - loss: 0.0097 - val_accuracy: 0.9892 - val_loss: 0.0440
# Epoch 96/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9971 - loss: 0.0069
# Epoch 96: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9971 - loss: 0.0069 - val_accuracy: 0.9928 - val_loss: 0.0201
# Epoch 97/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9980 - loss: 0.0078
# Epoch 97: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9980 - loss: 0.0078 - val_accuracy: 0.9928 - val_loss: 0.0633
# Epoch 98/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9976 - loss: 0.0078
# Epoch 98: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.9856 - val_loss: 0.0417
# Epoch 99/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9993 - loss: 0.0064
# Epoch 99: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9992 - loss: 0.0063 - val_accuracy: 0.9928 - val_loss: 0.0150
# Epoch 100/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 100: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9928 - val_loss: 0.0139
# Epoch 101/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 101: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9928 - val_loss: 0.0176
# Epoch 102/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9963 - loss: 0.0084
# Epoch 102: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9964 - loss: 0.0083 - val_accuracy: 0.9675 - val_loss: 0.1254
# Epoch 103/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 103: val_accuracy did not improve from 0.99639
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9856 - val_loss: 0.0453
# Best model saved at: CNN2D_results/Imbalanced-Ratio-Spectrogram-BatchNorm/best_model_fold_5.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Best model loaded successfully!
# 2025-07-03 04:22:25.929796: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-07-03 04:22:25.930765: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 409ms/step
# 2025-07-03 04:22:44.414673: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-07-03 04:22:44.414972: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step
#
# Average Training Metrics Across Folds:
# Accuracy: 0.9998 ± 0.0004
# Precision: 0.9998 ± 0.0003
# Recall: 0.9998 ± 0.0004
# F1 Score: 0.9998 ± 0.0004
# Log Loss: 0.0020 ± 0.0019
# Balanced Accuracy: 0.9988 ± 0.0025
#
# Average Test Metrics Across Folds:
# Accuracy: 0.9849 ± 0.0058
# Precision: 0.9874 ± 0.0035
# Recall: 0.9849 ± 0.0058
# F1 Score: 0.9844 ± 0.0060
# Log Loss: 0.0364 ± 0.0049
# Balanced Accuracy: 0.9100 ± 0.0343
#
# Blocks per class in X_train:
# Condition  Blocks
#    Normal    1208
#   RE 0.18      20
#   IR 0.18      20
#   OR 0.18      20
#   RE 0.36      20
#   IR 0.36      20
#   OR 0.36      20
#   RE 0.54      20
#   IR 0.54      20
#   OR 0.54      20
#
# X_train_split and Y_train distribution:
# Condition  Blocks
#    Normal    1208
#   RE 0.18      20
#   IR 0.18      20
#   OR 0.18      20
#   RE 0.36      20
#   IR 0.36      20
#   OR 0.36      20
#   RE 0.54      20
#   IR 0.54      20
#   OR 0.54      20
#
# X_test_split and Y_test distribution:
# Condition  Blocks
#    Normal     303
#   RE 0.18       6
#   IR 0.18       6
#   OR 0.18       6
#   RE 0.36       6
#   IR 0.36       6
#   OR 0.36       6
#   RE 0.54       6
#   IR 0.54       6
#   OR 0.54       6
#
# y_train_split distribution (assumed):
# Condition  Blocks
#    Normal    1208
#   RE 0.18      20
#   IR 0.18      20
#   OR 0.18      20
#   RE 0.36      20
#   IR 0.36      20
#   OR 0.36      20
#   RE 0.54      20
#   IR 0.54      20
#   OR 0.54      20
#
# y_test_split distribution (assumed):
# Condition  Blocks
#    Normal     303
#   RE 0.18       6
#   IR 0.18       6
#   OR 0.18       6
#   RE 0.36       6
#   IR 0.36       6
#   OR 0.36       6
#   RE 0.54       6
#   IR 0.54       6
#   OR 0.54       6

# %% [markdown]
# ## Multiclass Classification CNN Model Evaluation with Imbalanced Data

# %%
# Aggregated metrics
CNN_2D_train_accuracy = np.mean(accuracy_1D) * 100
CNN_2D_test_accuracy = np.mean(accuracy_1D_test) * 100
CNN_2D_train_precision = np.mean(precision_1D) * 100
CNN_2D_test_precision = np.mean(precision_1D_test) * 100
CNN_2D_train_recall = np.mean(recall_1D) * 100
CNN_2D_test_recall = np.mean(recall_1D_test) * 100
CNN_2D_train_f1 = np.mean(f1_1D) * 100
CNN_2D_test_f1 = np.mean(f1_1D_test) * 100
CNN_2D_train_log_loss = np.mean(log_loss_1D)
CNN_2D_test_log_loss = np.mean(log_loss_1D_test)
CNN_2D_train_balanced_accuracy = np.mean(balanced_accuracy_1D) * 100  # Average balanced accuracy for train set
CNN_2D_test_balanced_accuracy = np.mean(balanced_accuracy_1D_test) * 100  # Average balanced accuracy for test set

# Print Aggregated metrics
print(f"Train Accuracy: {CNN_2D_train_accuracy:.2f}%")
print(f"Test Accuracy: {CNN_2D_test_accuracy:.2f}%")
print(f"Train Precision: {CNN_2D_train_precision:.2f}%")
print(f"Test Precision: {CNN_2D_test_precision:.2f}%")
print(f"Train Recall: {CNN_2D_train_recall:.2f}%")
print(f"Test Recall: {CNN_2D_test_recall:.2f}%")
print(f"Train F1-score: {CNN_2D_train_recall:.2f}%")
print(f"Test F1-score: {CNN_2D_test_recall:.2f}%")
print(f"Train Log Loss: {CNN_2D_train_log_loss:.4f}")
print(f"Test Log Loss: {CNN_2D_test_log_loss:.4f}")
print(f"Train Balanced Accuracy: {CNN_2D_train_balanced_accuracy:.2f}%")
print(f"Test Balanced Accuracy: {CNN_2D_test_balanced_accuracy:.2f}%")

# Confusion Matrix Calculation

def ConfusionMatrix(Model, X, y):
    y_pred_proba = Model.predict(X)  # Use Model.model instead of Model
    y_pred = np.argmax(y_pred_proba, axis=1)  # Convert probabilities to class labels
    y_true = np.argmax(y, axis=1)  # Convert one-hot labels to class indices
    return confusion_matrix(y_true, y_pred)

# Plot results - CNN 1D
plt.figure(1)
plt.title('Confusion Matrix - CNN 2D Train')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_train, Y_train), annot=True, fmt='d', annot_kws={"fontsize":8}, cmap="YlGnBu")
plt.show()

plt.figure(2)
plt.title('Confusion Matrix - CNN 2D Test')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_test, Y_test), annot=True, fmt='d', annot_kws={"fontsize":8}, cmap="YlGnBu")
plt.show()

plt.figure(3)
plt.title('Train - Accuracy - CNN 2D')
plt.bar(np.arange(1, kSplits + 1), [i * 100 for i in accuracy_1D])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70, 100])
plt.show()

plt.figure(4)
plt.title('Train vs Test Accuracy - CNN 1D')
plt.bar([1, 2], [CNN_2D_train_accuracy, CNN_2D_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('sets')
plt.xticks([1, 2], ['Train', 'Test'])
plt.ylim([70, 100])
plt.show()
# Out:
# Train Accuracy: 99.98%
# Test Accuracy: 98.49%
# Train Precision: 99.98%
# Test Precision: 98.74%
# Train Recall: 99.98%
# Test Recall: 98.49%
# Train F1-score: 99.98%
# Test F1-score: 98.49%
# Train Log Loss: 0.0020
# Test Log Loss: 0.0364
# Train Balanced Accuracy: 99.88%
# Test Balanced Accuracy: 91.00%
# 2025-07-03 06:20:53.800130: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-07-03 06:20:53.803353: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 17s 388ms/step
# 2025-07-03 06:21:11.376807: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-07-03 06:21:11.377075: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step

# %%
# Create DataFrame from per-fold metrics
metrics_df = pd.DataFrame({
    'Fold': np.arange(1, kSplits + 1),
    
    'Train Accuracy (%)': np.array(accuracy_1D) * 100,
    'Test Accuracy (%)': np.array(accuracy_1D_test) * 100,

    'Train Precision (%)': np.array(precision_1D) * 100,
    'Test Precision (%)': np.array(precision_1D_test) * 100,

    'Train Recall (%)': np.array(recall_1D) * 100,
    'Test Recall (%)': np.array(recall_1D_test) * 100,

    'Train F1-score (%)': np.array(f1_1D) * 100,
    'Test F1-score (%)': np.array(f1_1D_test) * 100,

    'Train Log Loss': log_loss_1D,
    'Test Log Loss': log_loss_1D_test,

    'Train Balanced Accuracy (%)': np.array(balanced_accuracy_1D) * 100,
    'Test Balanced Accuracy (%)': np.array(balanced_accuracy_1D_test) * 100,
})

metrics_df
# Out:
#    Fold  Train Accuracy (%)  Test Accuracy (%)  Train Precision (%)  \
# 0     1           100.00000          98.319328           100.000000
# 1     2           100.00000          98.879552           100.000000
# 2     3            99.90991          98.599440            99.915209
# 3     4           100.00000          97.478992           100.000000
# 4     5           100.00000          99.159664           100.000000
#
#    Test Precision (%)  Train Recall (%)  Test Recall (%)  Train F1-score (%)  \
# 0           98.443377         100.00000        98.319328          100.000000
# 1           98.847539         100.00000        98.879552          100.000000
# 2           98.723489          99.90991        98.599440           99.909822
# 3           98.347339         100.00000        97.478992          100.000000
# 4           99.339736         100.00000        99.159664          100.000000
#
#    Test F1-score (%)  Train Log Loss  Test Log Loss  \
# 0          98.275898        0.004203       0.036754
# 1          98.824705        0.000519       0.029400
# 2          98.556010        0.004492       0.041966
# 3          97.394230        0.000574       0.041475
# 4          99.172256        0.000451       0.032582
#
#    Train Balanced Accuracy (%)  Test Balanced Accuracy (%)
# 0                      100.000                   90.000000
# 1                      100.000                   93.333333
# 2                       99.375                   91.666667
# 3                      100.000                   85.000000
# 4                      100.000                   95.000000

# %%
## turn into excel
metrics_df.to_excel(os.path.join(foldername, "Imbalanced_CNN2D_Metrics.xlsx"), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ## turn into excel
# ----> 2 metrics_df.to_excel(os.path.join(foldername, "Imbalanced_CNN2D_Metrics.xlsx"), index=False)
#
# NameError: name 'metrics_df' is not defined
