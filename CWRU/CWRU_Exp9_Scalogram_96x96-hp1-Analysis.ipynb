# %% [markdown]
# # CWRU Bearing Fault Diagnosis with Scalogram Inputs
# ## Overview
# - **Dataset**: CWRU Bearing Data (1HP load, various fault types and sizes)
# - **Input**: 96x96 pixel spectrogram or scalogram images
# - **Model**: CNN with three stages of double conv layers (32, 64, 128 filters), max pooling, and two dense layers
# - **Training**: 5-fold stratified cross-validation with early stopping
# - **Evaluation**: Accuracy, confusion matrices, and fold-wise performance plots
#
# ## Requirements
# - Python libraries: tensorflow, numpy, scipy, scikit-learn, matplotlib, seaborn, pywt, skimage
# - CWRU dataset files in 'CWRU_BearingData_Load_1HP' folder
#
# Run cells sequentially to load data, preprocess, train the model, and evaluate results.

# %%
# Setup for Reproducibility
import tensorflow as tf
import numpy as np
import random
import os

# Set a fixed seed value for reproducibility
SEED = 1
random.seed(SEED)            # Python random module
np.random.seed(SEED)         # NumPy
tf.random.set_seed(SEED)     # TensorFlow

# Enforce deterministic behavior for GPU operations
os.environ['TF_DETERMINISTIC_OPS'] = '1'  # Ensure deterministic execution
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # Deterministic cuDNN algorithms

# Control GPU memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)  # Enable memory growth

# Restrict parallelism
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# Import additional libraries
import scipy.io
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from skimage.transform import resize
import pywt  # For wavelet transform

# %% [markdown]
# ## Load CWRU Bearing Data
#
# The `ImportData` function loads the CWRU dataset files (.mat) containing vibration signals for normal and fault conditions (inner race, ball, outer race) at various fault sizes under a 2HP load. The data is stored in a list for further processing.

# %%
def ImportData():
    folder_path = 'CWRU_BearingData_Load_1HP'
    file_paths = [
        os.path.join(folder_path, '98.mat'),
        os.path.join(folder_path, '110.mat'),
        os.path.join(folder_path, '123.mat'),
        os.path.join(folder_path, '136.mat'),
        os.path.join(folder_path, '175.mat'),
        os.path.join(folder_path, '190.mat'),
        os.path.join(folder_path, '202.mat'),
        os.path.join(folder_path, '214.mat'),
        os.path.join(folder_path, '227.mat'),
        os.path.join(folder_path, '239.mat')
    ]
    data_keys = [
        'X098_DE_time', 'X110_DE_time', 'X123_DE_time', 'X136_DE_time',
        'X175_DE_time', 'X190_DE_time', 'X202_DE_time', 'X214_DE_time',
        'X227_DE_time', 'X239_DE_time'
    ]
    data = [scipy.io.loadmat(fp)[key] for fp, key in zip(file_paths, data_keys)]
    return data

# %% [markdown]
# ## Time-Frequency Image Generation
#
# The following functions generate spectrogram and scalogram images from vibration signal segments, as per Verstraete et al. (2017):
# - **Spectrogram**: Uses Short-Time Fourier Transform (STFT) with a Hann window, 256-point segments, and 128-point overlap. Images are normalized and resized to 96x96 pixels.
# - **Scalogram**: Uses Continuous Wavelet Transform (CWT) with the Morlet wavelet, scales 1 to 128. Magnitude is normalized and resized to 96x96 pixels.

# %%
def min_max_norm(ary):
    ary = (ary - ary.min()) / np.abs(ary.max() - ary.min())
    return ary

def generate_spectrogram_image(data_y_vector, image_shape=(96, 96)):
    """
    Calculate the spectrogram of an array data_y_vector and resize it to image_shape.
    """
    fs = 48000
    f, t, sxx = signal.spectrogram(
        data_y_vector,
        fs,
        nperseg=256,
        # noverlap=128,
        window='hann'
    )
    sxx = min_max_norm(sxx)
    sxx = resize(sxx, image_shape, mode='constant', anti_aliasing=True)
    return sxx

def generate_scalogram_image(data_y_vector, image_shape=(96, 96)):
    """
    Calculate the scalogram using Morlet wavelet and resize it to image_shape.
    """
    fs = 48000
    scales = np.arange(1, 128)  # Adjust scales for Morlet wavelet
    coef, freqs = pywt.cwt(
        data_y_vector,
        scales,
        'morl',
        sampling_period=1/fs
    )
    coef = np.abs(coef)  # Use magnitude
    coef = min_max_norm(coef)
    coef = resize(coef, image_shape, mode='constant', anti_aliasing=True)
    return coef

# %% [markdown]
# ## Data Preprocessing
#
# The `Sampling` function segments the vibration signals into blocks, and `DataPreparation` generates spectrogram or scalogram images for each segment. Labels are created in one-hot encoded format (`Y_CNN`) for CNN training and as integers (`Y`) for stratification. The output is a 4D array of images and corresponding labels.

# %%
def Sampling(Data, interval_length, samples_per_block, ignore_points=0):
    adjusted_length = len(Data) - 2 * ignore_points
    No_of_blocks = (round(adjusted_length / interval_length) - round(samples_per_block / interval_length) - 1)
    SplitData = np.zeros([No_of_blocks, samples_per_block])
    for i in range(No_of_blocks):
        start_idx = ignore_points + i * interval_length
        SplitData[i, :] = Data[start_idx:(start_idx + samples_per_block)].T
    return SplitData

def DataPreparation(Data, interval_length, samples_per_block, image_type='scalogram'):
    """
    Prepare data by generating spectrogram or scalogram images.
    """
    X = []
    LabelPositional = []
    Label = []
    for count, data in enumerate(Data):
        SplitData = Sampling(data, interval_length, samples_per_block)
        images = []
        for segment in SplitData:
            if image_type == 'spectrogram':
                img = generate_spectrogram_image(segment)
            elif image_type == 'scalogram':
                img = generate_scalogram_image(segment)
            images.append(img)
        images = np.array(images)
        y = np.zeros([len(SplitData), 10])
        y[:, count] = 1
        y1 = np.zeros([len(SplitData), 1])
        y1[:, 0] = count
        X.append(images)
        LabelPositional.append(y)
        Label.append(y1)
    X = np.concatenate(X, axis=0)
    LabelPositional = np.concatenate(LabelPositional, axis=0)
    Label = np.concatenate(Label, axis=0)
    return X, LabelPositional, Label

# %% [markdown]
# ## CNN Model Definition
#
# The `CNN_2D` class defines the CNN architecture as per Verstraete et al. (2017):
# - Three stages, each with two convolutional layers (32, 64, 128 filters, 3x3 kernels) followed by 2x2 max pooling.
# - Two dense layers (100 units each) with dropout (0.5) before the second dense layer.
# - Output layer with 10 units (softmax) for 10-class classification.
# - Compiled with Adam optimizer and categorical crossentropy loss.

# %%
class CNN_2D():
    def __init__(self):
        self.model = self.CreateModel()

    def CreateModel(self):
        model = models.Sequential([
            layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(96, 96, 1)),
            layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
            layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
            layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
            layers.MaxPool2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(100, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(96, activation='relu'),
            layers.Dense(10, activation='softmax')
        ])
        model.compile(
            optimizer='adam',
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model

# %% [markdown]
# ## Main Execution
#
# This section executes the pipeline:
# - Loads and preprocesses data to generate 96x96 images (spectrogram or scalogram).
# - Splits data into training (80%) and test (20%) sets with stratification.
# - Performs 5-fold cross-validation with early stopping and model checkpointing.
# - Saves the best model for each fold.
#
# **Parameters**:
# - `image_type`: Set to 'scalogram' or 'spectrogram' to choose input type.
# - `image_shape`: 96x96 pixels for high accuracy (per Verstraete et al.).
# - `kSplits`: 5 for cross-validation.
# - `foldername`: Directory to save model checkpoints.

# %%
# Parameters
interval_length = 1600
samples_per_block = 1600
image_type = 'scalogram'  # Change to 'spectrogram' to use spectrograms
image_shape = (96, 96)
kSplits = 5
foldername = "CNN2D_results/Scalogram-HP1/"

from tensorflow.keras.callbacks import ModelCheckpoint #Saves the model with the highest validation accuracy for each fold
from tensorflow.keras.callbacks import EarlyStopping 
from tensorflow.keras.models import load_model 

# Load and prepare data
Data = ImportData()
X, Y_CNN, Y = DataPreparation(Data, interval_length, samples_per_block, image_type=image_type)
Input_2D = X.reshape([-1, image_shape[0], image_shape[1], 1])
print(f"Shape of Input Data: {Input_2D.shape}")

# Train-test split
X_2D_train, X_2D_test, y_2D_train, y_2D_test, y_label_train, y_label_test = train_test_split(
    Input_2D, Y_CNN, Y, train_size=0.8, test_size=0.2, random_state=42, stratify=Y
)
# Out:
# Shape of Input Data: (2954, 96, 96, 1)

# %%
# Create a figure with four subplots, sharing the y-axis
fig, (plt1, plt2, plt3, plt4) = plt.subplots(1, 4, sharey=True, figsize=(12, 3), constrained_layout=True)

# Plot Normal state scalogram (index 0, assuming Normal samples are at the start)
plt1.set_xlabel("Time")
plt1.set_ylabel("Frequency")
plt1.set_title('Normal State')
plt1.imshow(Input_2D[0, :, :], aspect='auto', origin='lower', cmap='viridis')

# Plot Inner Race fault scalogram (index 1000, assuming Inner Race samples around this index)
plt2.set_xlabel("Time")
plt2.set_title('Inner Race Fault')
plt2.imshow(Input_2D[1000, :, :], aspect='auto', origin='lower', cmap='viridis')

# Plot Ball fault scalogram (index 2000, assuming Ball fault samples around this index)
plt3.set_xlabel("Time")
plt3.set_title('Ball Fault')
plt3.imshow(Input_2D[2000, :, :], aspect='auto', origin='lower', cmap='viridis')

# Plot Outer Race fault scalogram (index 2500, assuming Outer Race samples around this index)
plt4.set_xlabel("Time")
plt4.set_title('Outer Race Fault')
plt4.imshow(Input_2D[2500, :, :], aspect='auto', origin='lower', cmap='viridis')

# %%
# K-fold cross-validation
from sklearn.metrics import precision_score, recall_score, f1_score

kfold = StratifiedKFold(n_splits=kSplits, random_state=42, shuffle=True)
accuracy_train = []
accuracy_val = []
accuracy_test = []
precision_val = []
recall_val = []
f1_val = []
pred_all_val = np.zeros([len(X_2D_train), 10])
y_2D_val = np.zeros([len(X_2D_train), 10])
kfold_test_len = []
fl1 = 0
k = 1

early_stop = EarlyStopping(monitor='val_accuracy', patience=50, restore_best_weights=True)

# Train the model
for fold, (train, test) in enumerate(kfold.split(X_2D_train, y_label_train)):
    checkpoint_filepath = foldername + f"best_model_{k}.h5"
    checkpoint = ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
    Classification_2D = CNN_2D()
    history = Classification_2D.model.fit(
        X_2D_train[train], y_2D_train[train],
        validation_data=(X_2D_train[test], y_2D_train[test]),
        epochs=200,
        verbose=1,
        callbacks=[checkpoint, early_stop]
    )
    print(f"Best model saved at: {checkpoint_filepath}")
    CNN_2D_best_model = load_model(checkpoint_filepath)
    print("Best model loaded successfully!")
    
    fl2 = fl1 + len(test)
    pred_all_val[fl1:fl2, :] = CNN_2D_best_model.predict(X_2D_train[test])
    y_2D_val[fl1:fl2, :] = y_2D_train[test]
    kfold_test_len.append(fl2 - fl1)
    fl1 = fl2

    train_loss, train_accuracy = CNN_2D_best_model.evaluate(X_2D_train[train], y_2D_train[train])
    accuracy_train.append(train_accuracy)
    val_loss, val_accuracy = CNN_2D_best_model.evaluate(X_2D_train[test], y_2D_train[test])
    accuracy_val.append(val_accuracy)
    test_loss, test_accuracy = CNN_2D_best_model.evaluate(X_2D_test, y_2D_test)
    accuracy_test.append(test_accuracy)

    # Calculate precision, recall, and F1 score for validation set
    y_pred_val = np.argmax(CNN_2D_best_model.predict(X_2D_train[test]), axis=1)
    y_true_val = np.argmax(y_2D_train[test], axis=1)
    precision_val.append(precision_score(y_true_val, y_pred_val, average='weighted'))
    recall_val.append(recall_score(y_true_val, y_pred_val, average='weighted'))
    f1_val.append(f1_score(y_true_val, y_pred_val, average='weighted'))


    
    k += 1
# Out:
# /Users/Gayathri/pyenvs/tf-env/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 2025-06-16 16:13:24.721156: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-16 16:13:24.722001: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2783 - loss: 1.9343
# 2025-06-16 16:14:40.123289: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-16 16:14:40.124233: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Epoch 1: val_accuracy improved from -inf to 0.78224, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.2807 - loss: 1.9277 - val_accuracy: 0.7822 - val_loss: 0.6248
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7683 - loss: 0.6725
# Epoch 2: val_accuracy did not improve from 0.78224
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7688 - loss: 0.6712 - val_accuracy: 0.7294 - val_loss: 0.7510
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8230 - loss: 0.4769
# Epoch 3: val_accuracy improved from 0.78224 to 0.92178, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8233 - loss: 0.4758 - val_accuracy: 0.9218 - val_loss: 0.2068
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8735 - loss: 0.3313
# Epoch 4: val_accuracy improved from 0.92178 to 0.97040, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8737 - loss: 0.3308 - val_accuracy: 0.9704 - val_loss: 0.0972
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9143 - loss: 0.2392
# Epoch 5: val_accuracy improved from 0.97040 to 0.97252, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9144 - loss: 0.2390 - val_accuracy: 0.9725 - val_loss: 0.0977
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9109 - loss: 0.2478
# Epoch 6: val_accuracy did not improve from 0.97252
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9110 - loss: 0.2479 - val_accuracy: 0.9619 - val_loss: 0.0960
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9308 - loss: 0.1765
# Epoch 7: val_accuracy did not improve from 0.97252
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9307 - loss: 0.1768 - val_accuracy: 0.9704 - val_loss: 0.0984
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9410 - loss: 0.1674
# Epoch 8: val_accuracy did not improve from 0.97252
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9409 - loss: 0.1675 - val_accuracy: 0.9619 - val_loss: 0.1068
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9478 - loss: 0.1475
# Epoch 9: val_accuracy improved from 0.97252 to 0.97674, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9477 - loss: 0.1477 - val_accuracy: 0.9767 - val_loss: 0.0723
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9482 - loss: 0.1241
# Epoch 10: val_accuracy did not improve from 0.97674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9484 - loss: 0.1238 - val_accuracy: 0.9493 - val_loss: 0.1450
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9503 - loss: 0.1472
# Epoch 11: val_accuracy did not improve from 0.97674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9503 - loss: 0.1474 - val_accuracy: 0.9577 - val_loss: 0.1468
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9500 - loss: 0.1490
# Epoch 12: val_accuracy did not improve from 0.97674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9501 - loss: 0.1487 - val_accuracy: 0.9767 - val_loss: 0.0650
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9665 - loss: 0.1066
# Epoch 13: val_accuracy improved from 0.97674 to 0.98309, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9665 - loss: 0.1066 - val_accuracy: 0.9831 - val_loss: 0.0716
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9676 - loss: 0.0954
# Epoch 14: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9675 - loss: 0.0957 - val_accuracy: 0.9662 - val_loss: 0.1289
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9462 - loss: 0.1663
# Epoch 15: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9462 - loss: 0.1662 - val_accuracy: 0.9810 - val_loss: 0.0898
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9688 - loss: 0.0777
# Epoch 16: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9687 - loss: 0.0781 - val_accuracy: 0.9641 - val_loss: 0.1237
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9647 - loss: 0.1189
# Epoch 17: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9647 - loss: 0.1187 - val_accuracy: 0.9662 - val_loss: 0.1226
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9685 - loss: 0.0911
# Epoch 18: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9686 - loss: 0.0909 - val_accuracy: 0.9725 - val_loss: 0.1218
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9746 - loss: 0.0787
# Epoch 19: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9745 - loss: 0.0787 - val_accuracy: 0.9662 - val_loss: 0.1126
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9652 - loss: 0.0915
# Epoch 20: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9652 - loss: 0.0915 - val_accuracy: 0.9810 - val_loss: 0.0684
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9655 - loss: 0.1122
# Epoch 21: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9655 - loss: 0.1122 - val_accuracy: 0.9746 - val_loss: 0.0841
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9716 - loss: 0.0734
# Epoch 22: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9718 - loss: 0.0732 - val_accuracy: 0.9725 - val_loss: 0.1477
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9646 - loss: 0.0823
# Epoch 23: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9646 - loss: 0.0824 - val_accuracy: 0.9746 - val_loss: 0.1036
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9753 - loss: 0.0580
# Epoch 24: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9752 - loss: 0.0579 - val_accuracy: 0.9831 - val_loss: 0.0954
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9850 - loss: 0.0503
# Epoch 25: val_accuracy did not improve from 0.98309
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9849 - loss: 0.0506 - val_accuracy: 0.9619 - val_loss: 0.1982
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9667 - loss: 0.1018
# Epoch 26: val_accuracy improved from 0.98309 to 0.98520, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9669 - loss: 0.1014 - val_accuracy: 0.9852 - val_loss: 0.0578
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0424
# Epoch 27: val_accuracy did not improve from 0.98520
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9875 - loss: 0.0427 - val_accuracy: 0.9725 - val_loss: 0.0994
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9789 - loss: 0.0497
# Epoch 28: val_accuracy did not improve from 0.98520
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9790 - loss: 0.0497 - val_accuracy: 0.9831 - val_loss: 0.0557
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9858 - loss: 0.0466
# Epoch 29: val_accuracy did not improve from 0.98520
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9857 - loss: 0.0466 - val_accuracy: 0.9831 - val_loss: 0.0866
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9705 - loss: 0.0961
# Epoch 30: val_accuracy did not improve from 0.98520
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9706 - loss: 0.0957 - val_accuracy: 0.9725 - val_loss: 0.0851
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9809 - loss: 0.0463
# Epoch 31: val_accuracy did not improve from 0.98520
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9809 - loss: 0.0463 - val_accuracy: 0.9662 - val_loss: 0.1579
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9811 - loss: 0.0473
# Epoch 32: val_accuracy improved from 0.98520 to 0.98731, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9812 - loss: 0.0473 - val_accuracy: 0.9873 - val_loss: 0.0535
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0305
# Epoch 33: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9912 - loss: 0.0307 - val_accuracy: 0.9831 - val_loss: 0.0694
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9771 - loss: 0.0705
# Epoch 34: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9771 - loss: 0.0706 - val_accuracy: 0.9831 - val_loss: 0.0390
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9716 - loss: 0.1059
# Epoch 35: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9715 - loss: 0.1061 - val_accuracy: 0.9746 - val_loss: 0.0805
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9788 - loss: 0.0551
# Epoch 36: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9789 - loss: 0.0550 - val_accuracy: 0.9577 - val_loss: 0.2352
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9865 - loss: 0.0390
# Epoch 37: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9866 - loss: 0.0389 - val_accuracy: 0.9852 - val_loss: 0.0983
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0261
# Epoch 38: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9893 - loss: 0.0262 - val_accuracy: 0.9704 - val_loss: 0.1062
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9886 - loss: 0.0354
# Epoch 39: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9886 - loss: 0.0356 - val_accuracy: 0.9725 - val_loss: 0.1343
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9737 - loss: 0.0759
# Epoch 40: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9737 - loss: 0.0759 - val_accuracy: 0.9831 - val_loss: 0.0789
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9770 - loss: 0.0857
# Epoch 41: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9769 - loss: 0.0860 - val_accuracy: 0.9810 - val_loss: 0.0867
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9772 - loss: 0.0587
# Epoch 42: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9772 - loss: 0.0587 - val_accuracy: 0.9767 - val_loss: 0.0853
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9747 - loss: 0.0706
# Epoch 43: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9748 - loss: 0.0703 - val_accuracy: 0.9852 - val_loss: 0.0633
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9897 - loss: 0.0325
# Epoch 44: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9897 - loss: 0.0326 - val_accuracy: 0.9831 - val_loss: 0.0898
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0490
# Epoch 45: val_accuracy did not improve from 0.98731
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9856 - loss: 0.0489 - val_accuracy: 0.9831 - val_loss: 0.0820
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9811 - loss: 0.0494
# Epoch 46: val_accuracy improved from 0.98731 to 0.98943, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9812 - loss: 0.0493 - val_accuracy: 0.9894 - val_loss: 0.0738
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - loss: 0.0477
# Epoch 47: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9836 - loss: 0.0478 - val_accuracy: 0.9831 - val_loss: 0.1312
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 0.0434
# Epoch 48: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9872 - loss: 0.0433 - val_accuracy: 0.9894 - val_loss: 0.0445
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 0.0257
# Epoch 49: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9898 - loss: 0.0258 - val_accuracy: 0.9831 - val_loss: 0.0725
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9859 - loss: 0.0362
# Epoch 50: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9860 - loss: 0.0362 - val_accuracy: 0.9641 - val_loss: 0.1403
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9727 - loss: 0.0616
# Epoch 51: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9728 - loss: 0.0615 - val_accuracy: 0.9641 - val_loss: 0.2206
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9844 - loss: 0.0462
# Epoch 52: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9845 - loss: 0.0459 - val_accuracy: 0.9852 - val_loss: 0.0818
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 0.0181
# Epoch 53: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9946 - loss: 0.0182 - val_accuracy: 0.9810 - val_loss: 0.0948
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9798 - loss: 0.0631
# Epoch 54: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9797 - loss: 0.0635 - val_accuracy: 0.9725 - val_loss: 0.1038
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9760 - loss: 0.0683
# Epoch 55: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9760 - loss: 0.0681 - val_accuracy: 0.9789 - val_loss: 0.0761
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9869 - loss: 0.0336
# Epoch 56: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9869 - loss: 0.0338 - val_accuracy: 0.9810 - val_loss: 0.0706
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0211
# Epoch 57: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9924 - loss: 0.0211 - val_accuracy: 0.9810 - val_loss: 0.0958
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9830 - loss: 0.0430
# Epoch 58: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9830 - loss: 0.0430 - val_accuracy: 0.9852 - val_loss: 0.0877
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9954 - loss: 0.0193
# Epoch 59: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9953 - loss: 0.0194 - val_accuracy: 0.9831 - val_loss: 0.0853
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9888 - loss: 0.0263
# Epoch 60: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9888 - loss: 0.0264 - val_accuracy: 0.9831 - val_loss: 0.1034
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0410
# Epoch 61: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9855 - loss: 0.0410 - val_accuracy: 0.9873 - val_loss: 0.0522
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0257
# Epoch 62: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9909 - loss: 0.0257 - val_accuracy: 0.9873 - val_loss: 0.1109
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0399
# Epoch 63: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9875 - loss: 0.0401 - val_accuracy: 0.9852 - val_loss: 0.0591
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0375
# Epoch 64: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9868 - loss: 0.0375 - val_accuracy: 0.9831 - val_loss: 0.0753
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0210
# Epoch 65: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9933 - loss: 0.0209 - val_accuracy: 0.9789 - val_loss: 0.1600
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0298
# Epoch 66: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9907 - loss: 0.0298 - val_accuracy: 0.9789 - val_loss: 0.1285
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9865 - loss: 0.0339
# Epoch 67: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9865 - loss: 0.0340 - val_accuracy: 0.9894 - val_loss: 0.0405
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.0178
# Epoch 68: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9938 - loss: 0.0180 - val_accuracy: 0.9746 - val_loss: 0.0967
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.0211
# Epoch 69: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9939 - loss: 0.0212 - val_accuracy: 0.9852 - val_loss: 0.0714
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0311
# Epoch 70: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9921 - loss: 0.0312 - val_accuracy: 0.9852 - val_loss: 0.0626
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9942 - loss: 0.0196
# Epoch 71: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9942 - loss: 0.0196 - val_accuracy: 0.9873 - val_loss: 0.1040
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0263
# Epoch 72: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9908 - loss: 0.0263 - val_accuracy: 0.9852 - val_loss: 0.0881
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0217
# Epoch 73: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9911 - loss: 0.0218 - val_accuracy: 0.9852 - val_loss: 0.1278
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - loss: 0.0236
# Epoch 74: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9890 - loss: 0.0237 - val_accuracy: 0.9789 - val_loss: 0.0871
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9863 - loss: 0.0367
# Epoch 75: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9863 - loss: 0.0367 - val_accuracy: 0.9831 - val_loss: 0.0486
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9906 - loss: 0.0301
# Epoch 76: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9906 - loss: 0.0301 - val_accuracy: 0.9894 - val_loss: 0.0729
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9908 - loss: 0.0260
# Epoch 77: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9907 - loss: 0.0261 - val_accuracy: 0.9810 - val_loss: 0.1174
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9822 - loss: 0.0632
# Epoch 78: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9821 - loss: 0.0635 - val_accuracy: 0.9852 - val_loss: 0.0617
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9902 - loss: 0.0294
# Epoch 79: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9901 - loss: 0.0297 - val_accuracy: 0.9789 - val_loss: 0.0659
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.0340
# Epoch 80: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9885 - loss: 0.0339 - val_accuracy: 0.9767 - val_loss: 0.1134
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9851 - loss: 0.0436
# Epoch 81: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9851 - loss: 0.0437 - val_accuracy: 0.9873 - val_loss: 0.0380
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0368
# Epoch 82: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9873 - loss: 0.0368 - val_accuracy: 0.9789 - val_loss: 0.0743
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0300
# Epoch 83: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9904 - loss: 0.0301 - val_accuracy: 0.9852 - val_loss: 0.0618
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 0.0197
# Epoch 84: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9946 - loss: 0.0197 - val_accuracy: 0.9852 - val_loss: 0.0908
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0232
# Epoch 85: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9920 - loss: 0.0233 - val_accuracy: 0.9831 - val_loss: 0.1258
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0264
# Epoch 86: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9922 - loss: 0.0264 - val_accuracy: 0.9662 - val_loss: 0.1876
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0215
# Epoch 87: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9907 - loss: 0.0216 - val_accuracy: 0.9852 - val_loss: 0.0780
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0325
# Epoch 88: val_accuracy did not improve from 0.98943
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.9916 - loss: 0.0325 - val_accuracy: 0.9873 - val_loss: 0.0907
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9928 - loss: 0.0176
# Epoch 89: val_accuracy improved from 0.98943 to 0.99154, saving model to CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - accuracy: 0.9928 - loss: 0.0176 - val_accuracy: 0.9915 - val_loss: 0.0498
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.9930 - loss: 0.0203
# Epoch 90: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2296s 39s/step - accuracy: 0.9930 - loss: 0.0203 - val_accuracy: 0.9915 - val_loss: 0.0694
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 195s/step - accuracy: 0.9972 - loss: 0.0105
# Epoch 91: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12129s 206s/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9831 - val_loss: 0.1171
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9938 - loss: 0.0127
# Epoch 92: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 278s 5s/step - accuracy: 0.9937 - loss: 0.0128 - val_accuracy: 0.9789 - val_loss: 0.1122
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9896 - loss: 0.0201
# Epoch 93: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9895 - loss: 0.0202 - val_accuracy: 0.9704 - val_loss: 0.1017
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9901 - loss: 0.0298
# Epoch 94: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9901 - loss: 0.0297 - val_accuracy: 0.9831 - val_loss: 0.0511
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9934 - loss: 0.0327
# Epoch 95: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9934 - loss: 0.0325 - val_accuracy: 0.9873 - val_loss: 0.1026
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0233
# Epoch 96: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9907 - loss: 0.0233 - val_accuracy: 0.9873 - val_loss: 0.0576
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9936 - loss: 0.0202
# Epoch 97: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9936 - loss: 0.0203 - val_accuracy: 0.9852 - val_loss: 0.0791
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9813 - loss: 0.0490
# Epoch 98: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9812 - loss: 0.0493 - val_accuracy: 0.9704 - val_loss: 0.1600
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9706 - loss: 0.0823
# Epoch 99: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9707 - loss: 0.0820 - val_accuracy: 0.9831 - val_loss: 0.0456
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.0577
# Epoch 100: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9843 - loss: 0.0576 - val_accuracy: 0.9810 - val_loss: 0.1033
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9870 - loss: 0.0342
# Epoch 101: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9870 - loss: 0.0341 - val_accuracy: 0.9873 - val_loss: 0.0948
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9953 - loss: 0.0166
# Epoch 102: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9953 - loss: 0.0166 - val_accuracy: 0.9810 - val_loss: 0.1272
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9865 - loss: 0.0280
# Epoch 103: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9866 - loss: 0.0280 - val_accuracy: 0.9831 - val_loss: 0.0608
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9875 - loss: 0.0288
# Epoch 104: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9876 - loss: 0.0288 - val_accuracy: 0.9789 - val_loss: 0.0931
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9943 - loss: 0.0154
# Epoch 105: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9943 - loss: 0.0153 - val_accuracy: 0.9789 - val_loss: 0.1911
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9851 - loss: 0.0536
# Epoch 106: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9851 - loss: 0.0535 - val_accuracy: 0.9662 - val_loss: 0.1837
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9936 - loss: 0.0317
# Epoch 107: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9936 - loss: 0.0317 - val_accuracy: 0.9810 - val_loss: 0.1077
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9948 - loss: 0.0147
# Epoch 108: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9949 - loss: 0.0147 - val_accuracy: 0.9894 - val_loss: 0.0670
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9969 - loss: 0.0143
# Epoch 109: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9969 - loss: 0.0144 - val_accuracy: 0.9789 - val_loss: 0.1394
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9959 - loss: 0.0104
# Epoch 110: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9959 - loss: 0.0104 - val_accuracy: 0.9810 - val_loss: 0.0624
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0185
# Epoch 111: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9911 - loss: 0.0185 - val_accuracy: 0.9894 - val_loss: 0.0804
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9901 - loss: 0.0329
# Epoch 112: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9902 - loss: 0.0327 - val_accuracy: 0.9810 - val_loss: 0.1179
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0296
# Epoch 113: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9915 - loss: 0.0296 - val_accuracy: 0.9767 - val_loss: 0.1388
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9878 - loss: 0.0314
# Epoch 114: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9879 - loss: 0.0311 - val_accuracy: 0.9852 - val_loss: 0.1216
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0117
# Epoch 115: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9946 - loss: 0.0117 - val_accuracy: 0.9852 - val_loss: 0.1047
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0263
# Epoch 116: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9904 - loss: 0.0261 - val_accuracy: 0.9767 - val_loss: 0.1373
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9918 - loss: 0.0219
# Epoch 117: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9918 - loss: 0.0219 - val_accuracy: 0.9873 - val_loss: 0.0855
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - loss: 0.0138
# Epoch 118: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9951 - loss: 0.0138 - val_accuracy: 0.9831 - val_loss: 0.0689
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9854 - loss: 0.0381
# Epoch 119: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9854 - loss: 0.0381 - val_accuracy: 0.9852 - val_loss: 0.0967
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.0243
# Epoch 120: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9928 - loss: 0.0243 - val_accuracy: 0.9725 - val_loss: 0.1127
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - loss: 0.0132
# Epoch 121: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9951 - loss: 0.0132 - val_accuracy: 0.9746 - val_loss: 0.1040
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0270
# Epoch 122: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9869 - loss: 0.0270 - val_accuracy: 0.9915 - val_loss: 0.0346
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.0219
# Epoch 123: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9952 - loss: 0.0218 - val_accuracy: 0.9810 - val_loss: 0.0984
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9969 - loss: 0.0097
# Epoch 124: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9968 - loss: 0.0097 - val_accuracy: 0.9852 - val_loss: 0.1056
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9960 - loss: 0.0144
# Epoch 125: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9959 - loss: 0.0145 - val_accuracy: 0.9831 - val_loss: 0.1159
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0234
# Epoch 126: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9907 - loss: 0.0234 - val_accuracy: 0.9662 - val_loss: 0.0995
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0291
# Epoch 127: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9910 - loss: 0.0290 - val_accuracy: 0.9810 - val_loss: 0.0866
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0205
# Epoch 128: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9920 - loss: 0.0206 - val_accuracy: 0.9894 - val_loss: 0.0715
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0161
# Epoch 129: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9933 - loss: 0.0163 - val_accuracy: 0.9873 - val_loss: 0.0811
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9899 - loss: 0.0347
# Epoch 130: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9899 - loss: 0.0350 - val_accuracy: 0.9852 - val_loss: 0.0791
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9838 - loss: 0.0699
# Epoch 131: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9839 - loss: 0.0694 - val_accuracy: 0.9873 - val_loss: 0.0646
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0202
# Epoch 132: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9945 - loss: 0.0201 - val_accuracy: 0.9831 - val_loss: 0.1126
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0203
# Epoch 133: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9917 - loss: 0.0202 - val_accuracy: 0.9873 - val_loss: 0.0942
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9950 - loss: 0.0194
# Epoch 134: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9950 - loss: 0.0194 - val_accuracy: 0.9873 - val_loss: 0.0637
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9950 - loss: 0.0140
# Epoch 135: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9949 - loss: 0.0140 - val_accuracy: 0.9915 - val_loss: 0.0481
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0197
# Epoch 136: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9933 - loss: 0.0197 - val_accuracy: 0.9810 - val_loss: 0.1217
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9980 - loss: 0.0092
# Epoch 137: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9979 - loss: 0.0094 - val_accuracy: 0.9683 - val_loss: 0.2797
# Epoch 138/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0357
# Epoch 138: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9912 - loss: 0.0356 - val_accuracy: 0.9852 - val_loss: 0.1203
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0434
# Epoch 139: val_accuracy did not improve from 0.99154
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9920 - loss: 0.0432 - val_accuracy: 0.9789 - val_loss: 0.1146
# Best model saved at: CNN2D_results/Scalogram-HP1/best_model_1.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Best model loaded successfully!
# 2025-06-16 23:16:41.932898: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-16 23:16:41.933816: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 376ms/step
# 2025-06-16 23:16:48.131130: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-16 23:16:48.131412: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 373ms/step - accuracy: 1.0000 - loss: 2.8871e-04
# 2025-06-16 23:17:10.787146: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-16 23:17:10.787447: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 375ms/step - accuracy: 0.9948 - loss: 0.0249
# 2025-06-16 23:17:16.582048: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-16 23:17:16.582345: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# ...
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9693 - loss: 0.0836
# Epoch 53: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9694 - loss: 0.0834 - val_accuracy: 0.9958 - val_loss: 0.0115
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9860 - loss: 0.0425
# Epoch 54: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9860 - loss: 0.0426 - val_accuracy: 0.9894 - val_loss: 0.0277
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0393
# Epoch 55: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9868 - loss: 0.0393 - val_accuracy: 0.9958 - val_loss: 0.0256
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0288
# Epoch 56: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9904 - loss: 0.0290 - val_accuracy: 0.9852 - val_loss: 0.0630
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9581 - loss: 0.1893
# Epoch 57: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9583 - loss: 0.1881 - val_accuracy: 0.9852 - val_loss: 0.0449
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9884 - loss: 0.0429
# Epoch 58: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9884 - loss: 0.0429 - val_accuracy: 0.9852 - val_loss: 0.0285
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9877 - loss: 0.0283
# Epoch 59: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9877 - loss: 0.0282 - val_accuracy: 0.9915 - val_loss: 0.0304
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - loss: 0.0506
# Epoch 60: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9835 - loss: 0.0510 - val_accuracy: 0.9936 - val_loss: 0.0299
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0463
# Epoch 61: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9873 - loss: 0.0462 - val_accuracy: 0.9979 - val_loss: 0.0077
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0180
# Epoch 62: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9944 - loss: 0.0181 - val_accuracy: 0.9894 - val_loss: 0.0272
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0256
# Epoch 63: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9925 - loss: 0.0257 - val_accuracy: 0.9936 - val_loss: 0.0119
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 0.0366
# Epoch 64: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9872 - loss: 0.0367 - val_accuracy: 0.9831 - val_loss: 0.0510
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9924 - loss: 0.0249
# Epoch 65: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9923 - loss: 0.0249 - val_accuracy: 0.9915 - val_loss: 0.0179
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0203
# Epoch 66: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9944 - loss: 0.0204 - val_accuracy: 0.9873 - val_loss: 0.0607
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9875 - loss: 0.0346
# Epoch 67: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9875 - loss: 0.0345 - val_accuracy: 0.9831 - val_loss: 0.0394
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0303
# Epoch 68: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9909 - loss: 0.0303 - val_accuracy: 0.9979 - val_loss: 0.0059
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0206
# Epoch 69: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9920 - loss: 0.0206 - val_accuracy: 0.9958 - val_loss: 0.0145
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9865 - loss: 0.0321
# Epoch 70: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9866 - loss: 0.0320 - val_accuracy: 0.9936 - val_loss: 0.0160
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0387
# Epoch 71: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9876 - loss: 0.0386 - val_accuracy: 0.9936 - val_loss: 0.0266
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9889 - loss: 0.0345
# Epoch 72: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9889 - loss: 0.0345 - val_accuracy: 0.9894 - val_loss: 0.0317
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9864 - loss: 0.0279
# Epoch 73: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9865 - loss: 0.0278 - val_accuracy: 0.9915 - val_loss: 0.0218
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9941 - loss: 0.0205
# Epoch 74: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9940 - loss: 0.0205 - val_accuracy: 0.9936 - val_loss: 0.0147
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.0150
# Epoch 75: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9952 - loss: 0.0150 - val_accuracy: 0.9894 - val_loss: 0.0315
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9877 - loss: 0.0458
# Epoch 76: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9877 - loss: 0.0458 - val_accuracy: 0.9936 - val_loss: 0.0225
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9881 - loss: 0.0352
# Epoch 77: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9881 - loss: 0.0352 - val_accuracy: 0.9915 - val_loss: 0.0204
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9960 - loss: 0.0129
# Epoch 78: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9960 - loss: 0.0129 - val_accuracy: 0.9979 - val_loss: 0.0066
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0224
# Epoch 79: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9925 - loss: 0.0225 - val_accuracy: 0.9979 - val_loss: 0.0099
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9914 - loss: 0.0315
# Epoch 80: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9914 - loss: 0.0316 - val_accuracy: 0.9936 - val_loss: 0.0188
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9879 - loss: 0.0302
# Epoch 81: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 170s 3s/step - accuracy: 0.9879 - loss: 0.0302 - val_accuracy: 0.9936 - val_loss: 0.0207
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9928 - loss: 0.0282
# Epoch 82: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 156s 3s/step - accuracy: 0.9928 - loss: 0.0283 - val_accuracy: 0.9936 - val_loss: 0.0288
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9857 - loss: 0.0346
# Epoch 83: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9857 - loss: 0.0346 - val_accuracy: 0.9936 - val_loss: 0.0148
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9968 - loss: 0.0116
# Epoch 84: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9968 - loss: 0.0119 - val_accuracy: 0.9852 - val_loss: 0.0353
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9919 - loss: 0.0214
# Epoch 85: val_accuracy did not improve from 0.99788
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9919 - loss: 0.0213 - val_accuracy: 0.9979 - val_loss: 0.0070
# Best model saved at: CNN2D_results/Scalogram-HP1/best_model_5.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Best model loaded successfully!
# 2025-06-17 16:19:17.423231: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 16:19:17.424549: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 415ms/step
# 2025-06-17 16:19:24.368522: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-17 16:19:24.368878: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 29s 479ms/step - accuracy: 0.9979 - loss: 0.0045
# 2025-06-17 16:19:53.631868: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-17 16:19:53.632541: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 467ms/step - accuracy: 0.9984 - loss: 0.0050
# 2025-06-17 16:20:01.060559: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-06-17 16:20:01.060903: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 442ms/step - accuracy: 0.9881 - loss: 0.0263
# 2025-06-17 16:20:09.497562: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 16:20:09.497878: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 406ms/step

# %% [markdown]
# ## Model Evaluation
#
# Evaluate the trained model by computing average accuracies across folds for training, validation, and test sets. Visualize performance with confusion matrices for train and test sets, and bar plots for fold-wise and train vs. test accuracies.

# %%
CNN_2D_train_accuracy = np.average(accuracy_train) * 100
print(f'CNN 2D train accuracy = {CNN_2D_train_accuracy}')
CNN_2D_val_accuracy = np.average(accuracy_val) * 100
print(f'CNN 2D validation accuracy = {CNN_2D_val_accuracy}')
CNN_2D_test_accuracy = np.average(accuracy_test) * 100
print(f'CNN 2D test accuracy = {CNN_2D_test_accuracy}')

def ConfusionMatrix(Model, X, y):
    y_pred = np.argmax(Model.predict(X), axis=1)
    ConfusionMat = confusion_matrix(np.argmax(y, axis=1), y_pred)
    return ConfusionMat

# Plot results
plt.figure(5)
plt.title('Confusion Matrix - CNN 2D Train')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_train, y_2D_train), annot=True, fmt='d', annot_kws={"fontsize":8}, cmap="YlGnBu")
plt.show()

plt.figure(6)
plt.title('Confusion Matrix - CNN 2D Test')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_test, y_2D_test), annot=True, fmt='d', annot_kws={"fontsize":8}, cmap="YlGnBu")
plt.show()

plt.figure(7)
plt.title('Train - Accuracy - CNN 2D')
plt.bar(np.arange(1, kSplits + 1), [i * 100 for i in accuracy_val])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70, 100])
plt.show()

plt.figure(8)
plt.title('Train vs Test Accuracy - CNN 2D')
plt.bar([1, 2], [CNN_2D_train_accuracy, CNN_2D_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1, 2], ['Train', 'Test'])
plt.ylim([70, 100])
plt.show()
# Out:
# CNN 2D train accuracy = 99.91535544395447
# CNN 2D validation accuracy = 99.53470468521118
# CNN 2D test accuracy = 99.22165870666504
# 2025-06-17 16:31:42.669846: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 16:31:42.671215: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 475ms/step
# 2025-06-17 16:32:18.603870: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 16:32:18.604811: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 444ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

CNN_2D_val_precision = np.average(precision_val) * 100
CNN_2D_val_recall = np.average(recall_val) * 100
CNN_2D_val_f1 = np.average(f1_val) * 100

# Calculate metrics for test set
y_pred_test = np.argmax(CNN_2D_best_model.predict(X_2D_test), axis=1)
y_true_test = np.argmax(y_2D_test, axis=1)
CNN_2D_test_precision = precision_score(y_true_test, y_pred_test, average='weighted') * 100
CNN_2D_test_recall = recall_score(y_true_test, y_pred_test, average='weighted') * 100
CNN_2D_test_f1 = f1_score(y_true_test, y_pred_test, average='weighted') * 100

print('CNN 2D Validation Precision = {:.2f}%'.format(CNN_2D_val_precision))
print('CNN 2D Validation Recall = {:.2f}%'.format(CNN_2D_val_recall))
print('CNN 2D Validation F1 Score = {:.2f}%'.format(CNN_2D_val_f1))
print('CNN 2D Test Precision = {:.2f}%'.format(CNN_2D_test_precision))
print('CNN 2D Test Recall = {:.2f}%'.format(CNN_2D_test_recall))
print('CNN 2D Test F1 Score = {:.2f}%'.format(CNN_2D_test_f1))

# Plot train vs test metrics
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(16, 4))
fig.suptitle('Train vs Test Metrics')

ax1.bar([1, 2], [CNN_2D_train_accuracy, CNN_2D_test_accuracy])
ax1.set_title('Accuracy')
ax1.set_ylabel('Accuracy (%)')
ax1.set_xticks([1, 2])
ax1.set_xticklabels(['Train', 'Test'])
ax1.set_ylim([70, 100])

ax2.bar([1, 2], [CNN_2D_val_precision, CNN_2D_test_precision])
ax2.set_title('Precision')
ax2.set_ylabel('Precision (%)')
ax2.set_xticks([1, 2])
ax2.set_xticklabels(['Train', 'Test'])
ax2.set_ylim([70, 100])

ax3.bar([1, 2], [CNN_2D_val_recall, CNN_2D_test_recall])
ax3.set_title('Recall')
ax3.set_ylabel('Recall (%)')
ax3.set_xticks([1, 2])
ax3.set_xticklabels(['Train', 'Test'])
ax3.set_ylim([70, 100])

ax4.bar([1, 2], [CNN_2D_val_f1, CNN_2D_test_f1])
ax4.set_title('F1 Score')
ax4.set_ylabel('F1 Score (%)')
ax4.set_xticks([1, 2])
ax4.set_xticklabels(['Train', 'Test'])
ax4.set_ylim([70, 100])

plt.tight_layout()
plt.show()
# Out:
# 2025-06-17 16:32:39.773238: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 16:32:39.773557: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 449ms/step
# CNN 2D Validation Precision = 99.55%
# CNN 2D Validation Recall = 99.53%
# CNN 2D Validation F1 Score = 99.53%
# CNN 2D Test Precision = 99.02%
# CNN 2D Test Recall = 98.98%
# CNN 2D Test F1 Score = 98.99%

# %%
# Visualize Test Set Predictions
y_proba_test = np.max(CNN_2D_best_model.predict(X_2D_test), axis=1)

# Select one sample per class (first occurrence)
unique_classes = np.unique(y_true_test)
selected_indices = [np.where(y_true_test == c)[0][0] for c in unique_classes]
num_samples = len(selected_indices)

# Condition labels
condition_labels = {
    0: 'Normal',
    1: 'Inner Race Fault 0.007"',
    2: 'Inner Race Fault 0.014"',
    3: 'Inner Race Fault 0.021"',
    4: 'Ball Fault 0.007"',
    5: 'Ball Fault 0.014"',
    6: 'Ball Fault 0.021"',
    7: 'Outer Race Fault 0.007"',
    8: 'Outer Race Fault 0.014"',
    9: 'Outer Race Fault 0.021"'
}
# Out:
# 2025-06-17 17:11:22.416304: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 17:11:22.417543: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 416ms/step

# %%
# Plot images with predictions
fig, axes = plt.subplots(2, (num_samples + 1) // 2, figsize=(15, 6))
axes = axes.flatten()

for idx, sample_idx in enumerate(selected_indices):
    img = X_2D_test[sample_idx, :, :, 0]  # 96x96 image
    true_label = y_true_test[sample_idx]
    pred_label = y_pred_test[sample_idx]
    proba = y_proba_test[sample_idx]
    
    # Plot image
    im = axes[idx].imshow(img, cmap='viridis', aspect='equal')
    
    # Set border color based on correctness
    border_color = 'green' if true_label == pred_label else 'red'
    for spine in axes[idx].spines.values():
        spine.set_edgecolor(border_color)
        spine.set_linewidth(2)
    
    # Title with true label, predicted label, and probability
    axes[idx].set_title(
        f"True: {condition_labels[true_label]}\n"
        f"Pred: {condition_labels[pred_label]}\n"
        f"Prob: {proba:.2f}",
        fontsize=8
    )
    axes[idx].axis('off')

# Remove empty subplots
for idx in range(len(selected_indices), len(axes)):
    axes[idx].axis('off')

plt.suptitle(f'{"Spectrograms" if image_type == "spectrogram" else "Scalograms"}: Test Set Predictions', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
checkpoint_filepath = "CNN2D_results/Scalogram-HP1/best_model_5.h5"  # Last fold
try:
    CNN_2D_best_model = load_model(checkpoint_filepath)
except Exception as e:
    raise Exception(f"Failed to load model from {checkpoint_filepath}: {e}")
    
print("Trained Model Summary:")
CNN_2D_best_model.summary()

# # Initialize model input by making a prediction
# try:
#     dummy_input = X_2D_test[:1]  # Use one sample (shape: [1, 96, 96, 1])
#     CNN_2D_best_model.predict(dummy_input, verbose=0)  # Initialize input layer
#     print("Dummy prediction successful, input layer initialized.")
# except Exception as e:
#     raise Exception(f"Error initializing model input: {e}")

y_proba_test = np.max(CNN_2D_best_model.predict(X_2D_test), axis=1)

# Extract features from the last dense layer (before softmax)
try:
    # Create new input layer to bypass .input issue
    input_shape = (96, 96, 1)  # Match X_2D_test
    new_input = layers.Input(shape=input_shape)
    # Pass through all layers up to second-to-last dense layer
    x = new_input
    for layer in CNN_2D_best_model.layers[:-1]:  # Exclude final softmax
        x = layer(x)
    feature_model_trained = models.Model(inputs=new_input, outputs=x)  # dense_16 (96 units)    
    features_trained = feature_model_trained.predict(X_2D_test, verbose=0)
    print("Features extracted successfully, shape trained:", features_trained.shape)
    
except Exception as e:
    raise Exception(f"Error extracting features: {e}")

# Apply t-SNE for 2D projection
try:
    tsne_trained = TSNE(n_components=2, random_state=1, perplexity=min(30, len(X_2D_test)-1))
    tsne_coords_trained = tsne.fit_transform(features_trained)
except Exception as e:
    raise Exception(f"Error in t-SNE projection: {e}")

# Create DataFrame for plotting
condition_labels = {
    0: 'Normal',
    1: 'Inner Race 0.007"',
    2: 'Inner Race 0.014"',
    3: 'Inner Race 0.021"',
    4: 'Ball 0.007"',
    5: 'Ball 0.014"',
    6: 'Ball 0.021"',
    7: 'Outer Race 0.007"',
    8: 'Outer Race 0.014"',
    9: 'Outer Race 0.021"'
}
df = pd.DataFrame({
    't-SNE X': tsne_coords_trained[:, 0],
    't-SNE Y': tsne_coords_trained[:, 1],
    'True Class': [condition_labels[y] for y in y_true_test],
    'Prediction Correct': ['Correct' if y_true_test[i] == y_pred_test[i] else 'Incorrect' for i in range(len(y_true_test))],
    'Probability': y_proba_test
})

# Plot scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df,
    x='t-SNE X',
    y='t-SNE Y',
    hue='True Class',
    style='Prediction Correct',
    size='Probability',
    sizes=(50, 200),
    alpha=0.7
)
plt.title(f'After training t-SNE Projection of Test Set Predictions\nPrecision: {CNN_2D_test_precision:.1f}%, Recall: {CNN_2D_test_recall:.1f}%, F1: {CNN_2D_test_f1:.1f}%', fontsize=14)
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Trained Model Summary:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_30 (Conv2D)              │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 100)            │     1,843,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 96)             │         9,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 10)             │           970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,140,400 (8.16 MB)
#  Trainable params: 2,140,398 (8.16 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# 2025-06-17 20:52:53.975635: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:52:53.976134: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step
# 2025-06-17 20:53:02.535770: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:53:02.536276: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# Features extracted successfully, shape trained: (591, 96)

# %% [markdown]
# # Cell for Interpretation of t-SNE Projection Figure
#
#
# ##Metrics:
# - Precision: 99.0% (proportion of positive identifications that were actually correct).
# - Recall: 99.0% (proportion of actual positives correctly identified).
# - F1 Score: 99.0% (harmonic mean of precision and recall, indicating overall balance).
#
# ## Overview
# - The figure is a t-SNE (t-distributed Stochastic Neighbor Embedding) projection of test set predictions from your CNN model for the CWRU bearing fault diagnosis task.
# - It visualizes how well the model separates 10 classes (1 normal, 9 fault conditions) and identifies prediction errors.
# - Generated by the scatter plot cell, it uses 2D t-SNE components to represent high-dimensional CNN features (96 dimensions from the `dense_16` layer).
#
# ## Key Elements of the Figure
# - **Axes**:
#   - **t-SNE Component 1 (x-axis)**: First dimension, ranging from -40 to +40.
#   - **t-SNE Component 2 (y-axis)**: Second dimension, ranging from -30 to +40.
#   - These are optimized coordinates preserving local similarities, not directly interpretable.
# - **Points**:
#   - Each point represents a test sample (e.g., a 96x96 spectrogram/scalogram image).
#   - True Class Legend:
#     Blue: Ball 0.014" (probability 0.95)
#     Green: Inner Race 0.007" (0.97)
#     Red: Inner Race 0.021" (0.94)
#     Purple: Outer Race 0.007" (0.92)
#     Orange: Outer Race 0.014" (0.88)
#     Pink: Outer Race 0.021" (0.86)
#     Cyan: Normal (0.98)
#     Brown: Ball 0.007" (0.96)
#     Yellow: Inner Race 0.014" (0.93)
#     Gray: Ball 0.021" (0.90)
#   - Clustered into groups reflecting the 10 classes.
# - **Color Coding (True Class)**:
#   - Colors indicate true class labels
#   - Same-color clusters suggest discriminative CNN features.
# - **Marker Style (Prediction Correctness)**:
#   - Circles (●): Correct predictions (predicted class matches true class).
#   - Crosses (×): Incorrect predictions.
#   - Few crosses indicate high accuracy.
# - **Point Size (Probability)**:
#   - Size reflects prediction probability (0.56 to 0.96).
#   - Larger points (e.g., 0.96) show high confidence; smaller points (e.g., 0.56) show lower confidence.
# - **Metrics**:
#   - Precision: 99.0%, Recall: 99.0%, F1: 99.0% (in title).
#   - Near-perfect scores reflect excellent performance.
#
# ## Interpretation
# - **Class Separation**:
#   - **Distinct Clusters**: Each class forms a distinct cluster, indicating that the CNN has learned features that effectively separate the classes in the high-dimensional space. For example:
#   - The cyan cluster (Normal) is well-separated on the right.
#   - The green cluster (Inner Race 0.007") and blue cluster (Ball 0.014") are distinct on the left and top.
#   - The purple, pink, and orange clusters (Outer Race variants) are grouped together but separable.
# - **Overlap**: Some minor overlap exists (e.g., between Inner Race 0.021" and Ball 0.021"), but it’s minimal, suggesting good but not perfect separation for similar fault sizes.
# - **Prediction Accuracy**:
#   - Majority of points are circles (correct), with few crosses (incorrect), aligning with 99.0% metrics.
#   - Incorrect predictions (crosses) near boundaries (e.g., "Inner Race 0.014"" vs. "Ball 0.021"") indicate similarity-based errors.
# - **Confidence Levels**:
#   - Large points (0.88–0.96) for correct predictions show high confidence.
#   - Smaller incorrect points (0.56–0.72) suggest lower certainty, as expected.
# - **Outliers and Noise**:
#   - Isolated points (e.g., lone cyan "Outer Race 0.007"" on the left) may be outliers or noisy samples.
#   - Worth investigating for data quality or model robustness.
#
# - **Model Performance**: Near-perfect metrics (99.0%) and dominant circles confirm excellent CNN performance, likely matching state-of-the-art (~99.5% per Verstraete et al.).
# - **Class Discriminability**: Clear clustering by true class shows effective scalogram feature extraction.
# - **Misclassification Patterns**: Incorrect predictions near similar classes suggest challenges with subtle differences, reasonable for the dataset.
# - **Confidence Insights**: High-probability correct points reinforce reliability; low-probability incorrect points highlight improvement areas (e.g., data augmentation).
# - **Visualization Quality**: t-SNE captures local structure, making it useful for high-dimensional feature visualization.
#
# ## Suggestions for Further Analysis
# - **Zoom into Clusters**:
#   - Focus on regions with crosses (e.g., "Inner Race 0.014"" vs. "Outer Race 0.014""):
#     ```python
#     df_subset = df[df['True Class'].isin(['Inner Race 0.014"', 'Outer Race 0.014"'])]
#     sns.scatterplot(data=df_subset, x='t-SNE X', y='t-SNE Y', hue='True Class', style='Prediction Correct', size='Probability')

# %%
df_subset = df[df['True Class'].isin(['Inner Race 0.014"', 'Outer Race 0.014"'])]
sns.scatterplot(data=df_subset, x='t-SNE X', y='t-SNE Y', hue='True Class', style='Prediction Correct', size='Probability')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_subset = df[df['True Class'].isin(['Inner Race 0.014"', 'Outer Race 0.014"'])]
#       2 sns.scatterplot(data=df_subset, x='t-SNE X', y='t-SNE Y', hue='True Class', style='Prediction Correct', size='Probability')
#
# NameError: name 'df' is not defined

# %%
untrained_model = models.Sequential([
layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(96, 96, 1)),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D((2, 2), padding='same'),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D((2, 2), padding='same'),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.MaxPool2D((2, 2), padding='same'),
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(96, activation='relu'),  # Second-to-last layer
    layers.Dense(10, activation='softmax')  # Output layer
])
print("Untrained model architecture rebuilt.")
untrained_model.summary()

# Extract features from the last dense layer (before softmax)

# Create new input layer to bypass .input issue
input_shape = (96, 96, 1)  # Match X_2D_test   
new_input_untrained = layers.Input(shape=input_shape)
x_untrained = new_input_untrained
for layer in untrained_model.layers[:-1]:
    x_untrained = layer(x_untrained)
feature_model_untrained = models.Model(inputs=new_input_untrained, outputs=x_untrained)
features_untrained = feature_model_untrained.predict(X_2D_test, verbose=0)

print("Features extracted successfully, shape untrained:", features_untrained.shape)

# Apply t-SNE for 2D projection
try:
    tsne_untrained = TSNE(n_components=2, random_state=1, perplexity=min(30, len(X_2D_test)-1))
    tsne_coords_untrained = tsne_untrained.fit_transform(features_untrained)
except Exception as e:
    raise Exception(f"Error in t-SNE projection: {e}")

# Create DataFrame for plotting
condition_labels = {
    0: 'Normal',
    1: 'Inner Race 0.007"',
    2: 'Inner Race 0.014"',
    3: 'Inner Race 0.021"',
    4: 'Ball 0.007"',
    5: 'Ball 0.014"',
    6: 'Ball 0.021"',
    7: 'Outer Race 0.007"',
    8: 'Outer Race 0.014"',
    9: 'Outer Race 0.021"'
}

y_true_test = np.argmax(y_2D_test, axis=1)
y_pred_test = np.argmax(feature_model_untrained.predict(X_2D_test, verbose=0), axis=1)
y_proba_test = np.max(feature_model_untrained.predict(X_2D_test, verbose=0), axis=1)
CNN_2D_test_precision_untrained = precision_score(y_true_test, y_pred_test, average='weighted') * 100
CNN_2D_test_recall_untrained  = recall_score(y_true_test, y_pred_test, average='weighted') * 100
CNN_2D_test_f1_untrained  = f1_score(y_true_test, y_pred_test, average='weighted') * 100

df = pd.DataFrame({
    't-SNE X': tsne_coords_untrained[:, 0],
    't-SNE Y': tsne_coords_untrained[:, 1],
    'True Class': [condition_labels[y] for y in y_true_test],
    'Prediction Correct': ['Correct' if y_true_test[i] == y_pred_test[i] else 'Incorrect' for i in range(len(y_true_test))],
    'Probability': y_proba_test
})

# Plot scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df,
    x='t-SNE X',
    y='t-SNE Y',
    hue='True Class',
    style='Prediction Correct',
    size='Probability',
    sizes=(50, 200),
    alpha=0.7
)
plt.title(f'Before training t-SNE Projection of Test Set Predictions\nPrecision: {CNN_2D_test_precision_untrained:.1f}%, Recall: {CNN_2D_test_recall_untrained:.1f}%, F1: {CNN_2D_test_f1_untrained:.1f}%', fontsize=14)
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Untrained model architecture rebuilt.
# /Users/Gayathri/pyenvs/tf-env/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_120 (Conv2D)             │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_121 (Conv2D)             │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_60 (MaxPooling2D) │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_122 (Conv2D)             │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_123 (Conv2D)             │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_61 (MaxPooling2D) │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_124 (Conv2D)             │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_125 (Conv2D)             │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_62 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_20 (Flatten)            │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 100)            │     1,843,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 96)             │         9,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 10)             │           970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,140,398 (8.16 MB)
#  Trainable params: 2,140,398 (8.16 MB)
#  Non-trainable params: 0 (0.00 B)
# 2025-06-17 20:59:19.801760: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:59:19.803614: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# Features extracted successfully, shape untrained: (591, 96)
# 2025-06-17 20:59:30.836033: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:59:30.836417: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:59:39.855825: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2025-06-17 20:59:39.856195: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# /Users/Gayathri/pyenvs/tf-env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/Gayathri/pyenvs/tf-env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
